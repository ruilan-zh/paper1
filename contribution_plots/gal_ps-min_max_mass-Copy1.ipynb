# %% [markdown]
# # 3D halo power spectrum

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.lines import Line2D

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)
color_list = palette_tab10

# %%
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rc("font", family="STIXGeneral", size=18)
plt.rcParams["mathtext.fontset"] = "stix"
plt.rcParams['figure.figsize'] = (2*10/3, 4)
plt.rcParams["legend.frameon"] = False


plt.rcParams["xtick.major.size"] = 5
plt.rcParams["ytick.major.size"] = 5
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["lines.linewidth"] = 2

# %%
odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"

# %%
with open(f"{odir1}/snap40/mvir/ps-intensity-gal_all.pickle", "rb") as f:
    Pk_mean_all = pickle.load(f)
    Pk_gal_all = pickle.load(f)
Pk_gal_all.attrs["shotnoise"]
# Out:
# 130.2059311058223

# %%
with open(f"{odir1}/snap40/mvir/ps-intensity-gal_all.pickle", "rb") as f:
    Pk_mean_all = pickle.load(f)
    Pk_gal_all = pickle.load(f)
Pk_gal_all.attrs["shotnoise"]

# %%
odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
with open(f"{odir1}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)

# %%
with open(f"{odir1}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_sum10 = pickle.load(f)
    Pk_sum10 = pickle.load(f)

# %%
with open(f"{odir1}/snap40/mvir/ps-intensity-sum_all.pickle", "rb") as f:
    Pk_sum_all = pickle.load(f)
    Pk_sum_all = pickle.load(f)

# %%
print(Pk_mean_gal10)
# Out:
# 13.364997965501184

# %%
logM_min = 10
logM_max = 11.3

# %%
logM_min = 13.5
logM_max = 14.45

# %%
logM_min = 13.6
logM_max = 14.1

# %%
dlogM = 0.1

# %%
arr =  np.round(np.arange(logM_min,logM_max, dlogM),1)

# %%
ik = 0

# %%
Pks = []
Pk_means = []
shot_list = []
group_shot_list = []
"""
with open(f"{odir}/snap40/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
    Pk_means.append(Pk_mean_gal10)
    Pks.append(Pk_gal10["power"].real[ik])
    shot_list.append(Pk_gal10.attrs["shotnoise"])
"""
odir = "/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_sphereX_res"
for mass in arr:
    
    if logM_min > 13:
        #fname = f"{odir}/snap40/mvir/logM/ps-intensity-gal_logM<{mass}.pickle"
        odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
        fname = f"{odir1}/snap40/mvir/logMmax/gal/logM{mass}.pickle"
        
        odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
        fname_group = f"{odir1}/snap40/mvir/logMmax/group/logM{mass}.pickle"
        with open(fname_group, "rb") as f:
            Pk_mean1 = pickle.load(f)
            Pk_gal1 = pickle.load(f)
            group_shot_list.append(Pk_gal1.attrs["shotnoise"])
    else:
        fname = f"{odir}/snap40/mvir/logM/ps-intensity-gal_logM{mass}.pickle"
    with open(fname, "rb") as f:
        
            Pk_mean1 = pickle.load(f)
            print(Pk_mean1)
            Pk_gal1 = pickle.load(f)
            Pk_means.append(Pk_mean1)
            Pks.append(Pk_gal1["power"].real[ik])
            #print(Pk_gal1.attrs["shotnoise"])
            shot_list.append(Pk_gal1.attrs["shotnoise"])
    
   
    
shot_arr = np.array(shot_list)
Pks_arr = np.array(Pks)
group_shot_arr = np.array(group_shot_list)
# Out:
# 13.364997965501184
# 13.35643332424719
# 13.344826624364822
# 13.329543608507446
# 13.309314060089878
# 13.282449501288829
# 13.246147473154469
# 13.19625365781258
# 13.126465472177014
# 13.02833601506279
# 12.891064512138811
# 12.692247159226465
# 12.41226208151664
# 12.033881518607407

# %%
arr_fof = np.round(np.arange(logM_min,logM_max, dlogM),1)

# %%
arr_all = np.round(np.arange(logM_min,logM_max, dlogM),1)

# %%
print(arr_all)
# Out:
# [10.  10.1 10.2 10.3 10.4 10.5 10.6 10.7 10.8 10.9 11.  11.1 11.2 11.3]

# %%
Pks_fof = []
Pk_means_fof = []
shot_list_fof = []
"""
with open(f"{odir}/snap40/fof/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
    Pk_means_fof.append(Pk_mean_gal10)
    Pks_fof.append(Pk_gal10["power"].real[ik])
    shot_list_fof.append(Pk_gal10.attrs["shotnoise"])
"""
odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
for mass in arr:
    with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1/gal/logMmin{mass}.pickle", "rb") as f:
        Pk_mean1 = pickle.load(f)
        Pk_gal1 = pickle.load(f)
        Pk_means_fof.append(Pk_mean1)
        Pks_fof.append(Pk_gal1["power"].real[ik])
        shot_list_fof.append(Pk_gal1.attrs["shotnoise"])
        
        
shot_fof_arr = np.array(shot_list_fof)
Pks_fof_arr = np.array(Pks_fof)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-83-923f6ccf627f> in <module>()
#      12 odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
#      13 for mass in arr:
# ---> 14     with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1/gal/logMmin{mass}.pickle", "rb") as f:
#      15         Pk_mean1 = pickle.load(f)
#      16         Pk_gal1 = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/gal_survey/logSFR1/gal/logMmin10.0.pickle'

# %%
Pks2 = []
Pk_means2 = []
shot_list2 = []
"""
with open(f"{odir}/snap40/fof/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
    Pk_means_fof.append(Pk_mean_gal10)
    Pks_fof.append(Pk_gal10["power"].real[ik])
    shot_list_fof.append(Pk_gal10.attrs["shotnoise"])
"""
odir1 = "/cosma/home/dp004/dc-zhan5/paper1/ps_data"
for mass in arr:
    with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1.6/gal/logMmax{mass}.pickle", "rb") as f:
        Pk_mean1 = pickle.load(f)
        Pk_gal1 = pickle.load(f)
        Pk_means2.append(Pk_mean1)
        Pks2.append(Pk_gal1["power"].real[ik])
        shot_list2.append(Pk_gal1.attrs["shotnoise"])
        
        
shot_arr2 = np.array(shot_list2)
Pks_arr2 = np.array(Pks2)

# %%
with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1/gal/logMmin10.pickle", "rb") as f:
    Pk_mean09 = pickle.load(f)
    Pk1 = pickle.load(f)
    
print(Pk1.attrs["shotnoise"])
# Out:
# 338.99130400566617

# %%
with open(f"{odir1}/snap40/mvir/gal_survey/Nmesh2447/logSFR1/gal/logMmin10.pickle", "rb") as f:
    Pk_mean09 = pickle.load(f)
    Pk3 = pickle.load(f)
    
print(Pk3.attrs["shotnoise"])
# Out:
# 338.5391146869085

# %%
with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1.6/gal/logMmin10.pickle", "rb") as f:
    Pk_mean10 = pickle.load(f)
    Pk16 = pickle.load(f)

# %%
with open(f"{odir1}/snap40/mvir/gal_survey/logSFR1.5/gal/logMmin10.pickle", "rb") as f:
    Pk_mean_lum15 = pickle.load(f)
    Pk_lum15 = pickle.load(f)

# %%
with open(f"{odir1}/snap40/mvir/gal_survey/logSFR0.9/gal/logMmin10.pickle", "rb") as f:
    Pk_mean_lum09 = pickle.load(f)
    Pk_09 = pickle.load(f)

# %%
import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
im = 6
arr_all[im]
# Out:
# 10.6

# %%
((Pks)/(Pk_gal_all["power"].real[ik]))[im]
# Out:
# 1.0071536400122623

# %%
(np.array(shot_arr)/Pk_gal_all.attrs["shotnoise"])[im]
# Out:
# 1.2301270711325771

# %%
(np.array(Pk_means)/(Pk_mean_all))[im]
# Out:
# 0.9005067627639561

# %%
(Pks)/(Pk_gal_all["power"].real[ik])

# %%
color_list3 = palette_tab10[3:4] + ["DodgerBlue", "Purple"]

# %%
plt.rcParams["legend.title_fontproperties"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-33eb06db1b7e> in <module>()
# ----> 1 plt.rcParams["legend.title_fontproperties"]
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     706             return get_data_path()
#     707
# --> 708         return dict.__getitem__(self, key)
#     709
#     710     def __repr__(self):
#
# KeyError: 'legend.title_fontproperties'

# %%
, title_fontproperties={"weight":"bold"}

# %%
from matplotlib.patches import Rectangle
fig,ax = plt.subplots()
linewidth1=1
plt.plot([arr_all[0],arr_all[-1]], [1,1], linestyle=(5, (10/linewidth1, 6/linewidth1)), color="k")
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")
plt.plot(arr_all, (Pks)/(Pk_gal_all["power"].real[ik]), linestyle="solid", label=r"$P_{\mathrm{clus}} (k=0.04)$", c=color_list[3
                                                                                                                                          ])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
#plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])
#plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum_all.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[1])


label_list = [r"$M_{\mathrm{vir}} > M_{\mathrm{min}}$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
#ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color=color_list[3], linestyle="dashdot", label=r"$P_{\rm shot}/ P_{\rm shot, all}$")
tot_ps_leg = Line2D([],[],color=color_list[3], linestyle="solid",label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")
intensity_leg = Line2D([],[],color=color_list[3], linestyle="dashed",label=r"$\overline{I}\ /\ \overline{I}_{\rm all}$")

bbox_to_anchor_grey=(0,0.9)

leg_list = [tot_ps_leg, shotnoise_ps_leg, intensity_leg ]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="upper left",fontsize=legend_fontsize, frameon=False)

plt.xlabel('log$_{10}$($M_\mathrm{min}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel("Ratio")
#plt.ylabel(r"$M > M_{\rm min}/{M > 10^8}$M$_\odot$ h$^{-1}$")
#ax.add_patch(Rectangle((10, 1), 0.5, 0.01, fill=False))
"""
# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
"""
#ax.tick_params(length=5)

ax.plot(arr_all, np.array(Pk_means)/Pk_mean_all, linestyle="dashed", color=color_list[3])
#plt.savefig("../figures/min_masses.pdf", format="pdf", bbox_inches="tight")

# %%
from matplotlib.patches import Rectangle
fig,ax = plt.subplots()
linewidth1=1
plt.plot([arr_all[0],arr_all[-1]], [1,1], linestyle=(5, (10/linewidth1, 6/linewidth1)), color="k")
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")
plt.plot(arr_all, (Pks)/(Pk_gal_all["power"].real[ik]), linestyle="solid", label=r"$P_{\mathrm{clus}} (k=0.04)$", c=color_list[3
                                                                                                                                          ])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
#plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])
#plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum_all.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[1])


label_list = [r"$M_{\mathrm{vir}} > M_{\mathrm{min}}$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
#ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color=color_list[3], linestyle="dashdot", label=r"$P_{\rm shot}/ P_{\rm shot, all}$")
tot_ps_leg = Line2D([],[],color=color_list[3], linestyle="solid",label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")
intensity_leg = Line2D([],[],color=color_list[3], linestyle="dashed",label=r"$\overline{I}\ /\ \overline{I}_{\rm all}$")

bbox_to_anchor_grey=(0,0.9)

leg_list = [tot_ps_leg, shotnoise_ps_leg, intensity_leg ]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="upper left",fontsize=legend_fontsize, frameon=False)

plt.xlabel('log$_{10}$($M_\mathrm{min}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel("Ratio")
#plt.ylabel(r"$M > M_{\rm min}/{M > 10^8}$M$_\odot$ h$^{-1}$")
#ax.add_patch(Rectangle((10, 1), 0.5, 0.01, fill=False))
"""
# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
"""
#ax.tick_params(length=5)

ax.plot(arr_all, np.array(Pk_means)/Pk_mean_all, linestyle="dashed", color=color_list[3])
#plt.savefig("../figures/min_masses.pdf", format="pdf", bbox_inches="tight")

# %%
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")

plt.plot(arr_all, len(arr_all)*[1], linestyle=(5, (10, 3)), color="k")
plt.plot(arr_all, (Pks)/(Pk_gal10["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[3])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")

plt.plot(arr_all, (Pks_fof)/(Pk10["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[1])
plt.plot(arr_all, np.array(shot_fof_arr)/Pk10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[1])

plt.plot(arr_all, (Pks2)/(Pk10_2["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[2])
plt.plot(arr_all, np.array(shot_arr2)/Pk10_2.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[2])

ax = plt.gca()

bbox_to_anchor_color = (1,0.5)
label_list = ["LIM", r"$\log\mathrm{SFR} > 0.9$", r"$\log\mathrm{SFR} > 1.5$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower right")

ax.add_artist(first_legend)

label_list = ["Intensity", r"$\log\mathrm{SFR} > 0.9$", r"$\log\mathrm{SFR} > 1.5$"]
solid_lines=[]
for i in range(1,3):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)
bbox_to_anchor_grey = (1,0)
bbox_to_anchor_color = (0.5,0.15)
legend_fontsize=18
first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower left", title="Galaxy survey")

ax.add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color="gray", linestyle="dashdot", label=r"$P^{\mathrm{gal}}_{\rm shot}/ P^{\mathrm{gal}}_{\rm shot, all}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color="gray",  label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")

bbox_to_anchor_grey = (1,0.75)
leg_list = [shotnoise_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

bbox_to_anchor_grey = (1,0)
leg_list = [shotnoise_subtracted_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

plt.xlabel('log$_{10}$(M$_\mathrm{max}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel(r"$\rm P(k)/P(k)_{TNG\ all}$")

#plt.savefig("../figures/max_masses_gal_survey.pdf", format="pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-26bdf06da71a> in <module>()
#       6 #plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")
#       7
# ----> 8 plt.plot(arr_all, (Pks_fof)/(Pk10["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[1])
#       9 plt.plot(arr_all, np.array(shot_fof_arr)/Pk10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[1])
#      10
#
# NameError: name 'Pk10' is not defined

# %%
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")

plt.plot(arr_all, len(arr_all)*[1], linestyle=(5, (10, 3)), color="k")
plt.plot(arr_all, (Pks)/(Pk_gal10["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[3])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")

plt.plot(arr_all, (Pks_fof)/(Pk1["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[1])
plt.plot(arr_all, np.array(shot_fof_arr)/Pk1.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[1])

plt.plot(arr_all, (Pks2)/(Pk16["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[2])
plt.plot(arr_all, np.array(shot_arr2)/Pk16.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[2])

ax = plt.gca()

bbox_to_anchor_color = (1,0.5)
label_list = ["LIM", r"$\log\mathrm{SFR} > 0.9$", r"$\log\mathrm{SFR} > 1.5$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower right")

ax.add_artist(first_legend)

label_list = ["Intensity", r"$\log\mathrm{SFR} > 1$", r"$\log\mathrm{SFR} > 1.6$"]
solid_lines=[]
for i in range(1,3):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)
bbox_to_anchor_grey = (1,0)
bbox_to_anchor_color = (0.5,0.15)
legend_fontsize=18
first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower left", title="Galaxy survey")

ax.add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color="gray", linestyle="dashdot", label=r"$P^{\mathrm{gal}}_{\rm shot}/ P^{\mathrm{gal}}_{\rm shot, all}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color="gray",  label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")

bbox_to_anchor_grey = (1,0.75)
leg_list = [shotnoise_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

bbox_to_anchor_grey = (1,0)
leg_list = [shotnoise_subtracted_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

plt.xlabel('log$_{10}$(M$_\mathrm{max}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel(r"$\rm P(k)/P(k)_{TNG\ all}$")

#plt.savefig("../figures/max_masses_gal_survey.pdf", format="pdf", bbox_inches="tight")

# %%
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")

plt.plot(arr_all, len(arr_all)*[1], linestyle=(5, (10, 3)), color="k")
plt.plot(arr_all, (Pks)/(Pk_gal10["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[3])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")

plt.plot(arr_all, (Pks_fof)/(Pk1["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[1])
plt.plot(arr_all, np.array(shot_fof_arr)/Pk1.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[1])

plt.plot(arr_all, (Pks2)/(Pk16["power"].real[ik]), label=r"$\rm P_{S} (k=0.04)$", c=color_list3[2])
plt.plot(arr_all, np.array(shot_arr2)/Pk16.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list3[2])

ax = plt.gca()

bbox_to_anchor_color = (1,0.5)
label_list = ["LIM", r"$\log\mathrm{SFR} > 0.9$", r"$\log\mathrm{SFR} > 1.5$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower right")

ax.add_artist(first_legend)

label_list = ["Intensity", r"$\log\mathrm{SFR} > 1$", r"$\log\mathrm{SFR} > 1.6$"]
solid_lines=[]
for i in range(1,3):
    solid_line = Line2D([],[],color=color_list3[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)
bbox_to_anchor_grey = (1,0)
bbox_to_anchor_color = (0.5,0.15)
legend_fontsize=18
first_legend = plt.legend(handles=solid_lines, frameon=False, bbox_to_anchor=bbox_to_anchor_color, loc="lower left", title="Galaxy survey")

ax.add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color="gray", linestyle="dashdot", label=r"$P^{\mathrm{gal}}_{\rm shot}/ P^{\mathrm{gal}}_{\rm shot, all}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color="gray",  label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")

bbox_to_anchor_grey = (1,0.75)
leg_list = [shotnoise_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

bbox_to_anchor_grey = (1,0)
leg_list = [shotnoise_subtracted_ps_leg]
leg2 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right", fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg2)

plt.xlabel('log$_{10}$(M$_\mathrm{max}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel(r"$\rm P(k)/P(k)_{TNG\ all}$")

#plt.savefig("../figures/max_masses_gal_survey.pdf", format="pdf", bbox_inches="tight")
# Out:
# Text(0, 0.5, '$\\rm P(k)/P(k)_{TNG\\ all}$')

# %%
plt.rcParams["xtick.major.size"] = 5
plt.rcParams["ytick.major.size"] = 5
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["lines.linewidth"] = 2

# %%
from matplotlib.patches import Rectangle
fig,ax = plt.subplots()
linewidth1=1
plt.plot([arr_all[0],arr_all[-1]], [1,1], linestyle=(5, (10/linewidth1, 6/linewidth1)), color="k")
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")
plt.plot(arr_all, (Pks)/(Pk_gal_all["power"].real[ik]), linestyle="solid", label=r"$P_{\mathrm{clus}} (k=0.04)$", c=color_list[3
                                                                                                                                          ])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
#plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
#plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])

label_list = [r"$M_{\mathrm{vir}} > M_{\mathrm{min}}$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
#ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color=color_list[3], linestyle="dashdot", label=r"$P_{\rm shot}/ P_{\rm shot, all}$")
tot_ps_leg = Line2D([],[],color=color_list[3], linestyle="solid",label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")
intensity_leg = Line2D([],[],color=color_list[3], linestyle="dashed",label=r"$\overline{I}\ /\ \overline{I}_{\rm all}$")

bbox_to_anchor_grey=(0,0.9)

leg_list = [tot_ps_leg, shotnoise_ps_leg, intensity_leg ]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="upper left",fontsize=legend_fontsize, frameon=False)

plt.xlabel('log$_{10}$($M_\mathrm{min}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel("Ratio")
#plt.ylabel(r"$M > M_{\rm min}/{M > 10^8}$M$_\odot$ h$^{-1}$")
#ax.add_patch(Rectangle((10, 1), 0.5, 0.01, fill=False))
"""
# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
"""
#ax.tick_params(length=5)

ax.plot(arr_all, np.array(Pk_means)/Pk_mean_all, linestyle="dashed", color=color_list[3])
#plt.savefig("../figures/min_masses.pdf", format="pdf", bbox_inches="tight")

# %%
i = 7
print(arr_all[i])
print((Pks/(Pk_gal_all["power"].real[ik]))[i])
# Out:
# 10.7
# 1.0125985668223665

# %%
from matplotlib.patches import Rectangle
fig,ax = plt.subplots()
linewidth1=1
plt.plot([arr_all[0],arr_all[-1]], [1,1], linestyle=(5, (10/linewidth1, 6/linewidth1)), color="k")
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")
plt.plot(arr_all, (Pks)/(Pk_gal10["power"].real[ik]), linestyle="solid", label=r"$P_{\mathrm{clus}} (k=0.04)$", c=color_list[3
                                                                                                                                          ])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")


#plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
#plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])

label_list = [r"$M_{\mathrm{vir}} > M_{\mathrm{min}}$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
#ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color=color_list[3], linestyle="dashdot", label=r"$P^{\mathrm{gal}}_{\rm shot}/ P^{\mathrm{gal}}_{\rm shot, all}$")
group_shotnoise_ps_leg = Line2D([],[],color="goldenrod", linestyle="dashdot", label=r"$P^{\mathrm{halo}}_{\rm shot}/ P^{\mathrm{halo}}_{\rm shot, all}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color_list[3], linestyle="solid",label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")
intensity_leg = Line2D([],[],color=color_list[3], linestyle="dashed",label=r"$\overline{I}\ /\ \overline{I}_{\rm all}$")

ax = plt.gca()
leg = ax.legend(handles=[intensity_leg],loc = "lower right", bbox_to_anchor=(1,0.45))
ax.add_artist(leg)

bbox_to_anchor_grey = (1,0.3)
leg_list = [shotnoise_ps_leg]
leg1 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg1)
bbox_to_anchor_grey = (1,0.15)
leg_list = [group_shotnoise_ps_leg]
leg1 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg1)
bbox_to_anchor_grey = (1,0)
leg_list = [shotnoise_subtracted_ps_leg ]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)

plt.xlabel('log$_{10}$($M_\mathrm{max}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel("Ratio")
#plt.ylabel(r"$M > M_{\rm min}/{M > 10^8}$M$_\odot$ h$^{-1}$")
#ax.add_patch(Rectangle((10, 1), 0.5, 0.01, fill=False))
"""
# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
"""
#ax.tick_params(length=5)

ax.plot(arr_all, np.array(Pk_means)/Pk_mean_gal10, linestyle="dashed", color=color_list[3])
#plt.savefig("../figures/max_masses.pdf", format="pdf", bbox_inches="tight")

# %%
from matplotlib.patches import Rectangle
fig,ax = plt.subplots()
linewidth1=1
plt.plot([arr_all[0],arr_all[-1]], [1,1], linestyle=(5, (10/linewidth1, 6/linewidth1)), color="k")
#plt.plot(arr, Pks/Pk_gal_all["power"].real[0], label=r"$\rm P_{S} (k=0.04)$")
plt.plot(arr_all, (Pks)/(Pk_gal10["power"].real[ik]), linestyle="solid", label=r"$P_{\mathrm{clus}} (k=0.04)$", c=color_list[3
                                                                                                                                          ])
plt.plot(arr_all, np.array(shot_arr)/Pk_gal10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c=color_list[3])
plt.plot(arr_all, np.array(group_shot_arr)/Pk_sum10.attrs["shotnoise"], linestyle="dashdot", label=r"P$_{\rm shot}$", c="goldenrod")


#plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
#plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])

label_list = [r"$M_{\mathrm{vir}} > M_{\mathrm{min}}$"]
solid_lines=[]
for i in range(1):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)

legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
#ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color=color_list[3], linestyle="dashdot", label=r"$P^{\mathrm{gal}}_{\rm shot}/ P^{\mathrm{gal}}_{\rm shot, all}$")
group_shotnoise_ps_leg = Line2D([],[],color="goldenrod", linestyle="dashdot", label=r"$P^{\mathrm{halo}}_{\rm shot}/ P^{\mathrm{halo}}_{\rm shot, all}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color_list[3], linestyle="solid",label=r"$P_{\rm tot}(k=0.04)/P_{\rm tot, all}(k=0.04)$")
intensity_leg = Line2D([],[],color=color_list[3], linestyle="dashed",label=r"$\overline{I}\ /\ \overline{I}_{\rm all}$")

ax = plt.gca()
leg = ax.legend(handles=[intensity_leg],loc = "lower right", bbox_to_anchor=(1,0.45))
ax.add_artist(leg)

bbox_to_anchor_grey = (1,0.3)
leg_list = [shotnoise_ps_leg]
leg1 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg1)
bbox_to_anchor_grey = (1,0.15)
leg_list = [group_shotnoise_ps_leg]
leg1 = plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)
ax.add_artist(leg1)
bbox_to_anchor_grey = (1,0)
leg_list = [shotnoise_subtracted_ps_leg ]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="lower right",fontsize=legend_fontsize, frameon=False)

plt.xlabel('log$_{10}$($M_\mathrm{max}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel("Ratio")
#plt.ylabel(r"$M > M_{\rm min}/{M > 10^8}$M$_\odot$ h$^{-1}$")
#ax.add_patch(Rectangle((10, 1), 0.5, 0.01, fill=False))
"""
# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
"""
#ax.tick_params(length=5)

ax.plot(arr_all, np.array(Pk_means)/Pk_mean_gal10, linestyle="dashed", color=color_list[3])
#plt.savefig("../figures/max_masses.pdf", format="pdf", bbox_inches="tight")

# %%
odir = "../ps_data"
fname = f"{odir}/snap40/mvir/logMmax/group/logM13.6.pickle"
with open(fname, "rb") as f:
    Pk_mean1 = pickle.load(f)
    Pk_gal1 = pickle.load(f)

# %%
odir = "../ps_data"
fname = f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle"
with open(fname, "rb") as f:
    Pk_mean1 = pickle.load(f)
    Pk_sum10 = pickle.load(f)

# %%
Pk_gal1.attrs["shotnoise"]/Pk_sum10.attrs["shotnoise"]
# Out:
# 0.9047255317953422

# %%
Pk_gal10.attrs["shotnoise"]/Pk_sum10.attrs["shotnoise"]
# Out:
# 0.42772761023693534

# %%
Pk_gal1["power"].real/Pk_gal10["power"].real
# Out:
# array([0.9099236 , 0.92700844, 0.94628072, 0.93944354, 0.94491001,
#        0.95335129, 0.93456671, 0.93679449, 0.94593231, 0.94710317,
#        0.93991993, 0.94973609, 0.94171925, 0.94650265, 0.94731662,
#        0.95183886, 0.94630828, 0.95738075, 0.96534696, 0.96963124,
#        0.96749267, 0.96848416, 0.97281105, 0.97055647, 0.97205921,
#        0.97548585, 0.97470202, 0.98187139, 0.97821668, 0.98957606,
#        0.99040644, 0.98867839, 0.99307085, 0.99633387, 0.99991494,
#        1.00135018, 1.00271714, 1.00416569, 1.01575534, 1.01599807,
#        1.02427263, 1.02082244, 1.02535872, 1.03179582, 1.03486767,
#        1.03528593, 1.04266681, 1.04117174, 1.0490116 , 1.05470718,
#        1.05669807, 1.06166272, 1.06584945, 1.06813337, 1.0720351 ,
#        1.07791759, 1.07979875, 1.08011154, 1.08682776, 1.08959021,
#        1.09217778, 1.09544688, 1.10000944, 1.10431976, 1.10030914,
#        1.10853309, 1.11373541, 1.11650217, 1.12088459, 1.12046421,
#        1.1295811 , 1.13384992, 1.1348033 , 1.14134753, 1.14460972,
#        1.14562124, 1.14545311, 1.14957451, 1.15623792, 1.15725146,
#        1.16463259, 1.16262776, 1.16840355, 1.16821529, 1.16952856,
#        1.17672017, 1.17714181, 1.18327984, 1.18606289, 1.18855884,
#        1.19138609, 1.19573479, 1.19873015, 1.20155749, 1.20298242,
#        1.20499466, 1.21242678, 1.21349884, 1.21605922, 1.22022735,
#        1.22537382, 1.22474493, 1.22741939, 1.23328374, 1.23578658,
#        1.23658775, 1.24112534, 1.24124058, 1.24445129, 1.24421154,
#        1.24771613, 1.25475906, 1.25432885, 1.2562561 , 1.25887622,
#        1.26311967, 1.26402305, 1.2647966 , 1.26744302, 1.27054052,
#        1.27217782, 1.27437881, 1.27815271, 1.27748428, 1.28041789,
#        1.28074723, 1.2806379 , 1.28488717, 1.28609298, 1.29033036,
#        1.29242224, 1.29678111, 1.29802728, 1.30099439, 1.30202586,
#        1.30493115, 1.30962719, 1.31149517, 1.31272952, 1.31421516,
#        1.31739835, 1.31991105, 1.32333873, 1.32362528, 1.32416269,
#        1.32691273, 1.33086464, 1.33458488, 1.3355563 , 1.33651141,
#        1.34019171, 1.34025616, 1.34377544, 1.34438256, 1.3495124 ,
#        1.34708293, 1.35055259, 1.35079851, 1.35260261, 1.35334734,
#        1.35282518, 1.35812376, 1.35994586, 1.36069308, 1.3606342 ,
#        1.36512285, 1.36684944, 1.37055432, 1.36927653, 1.37018905,
#        1.37390124, 1.37467585, 1.37719128, 1.38003518, 1.38119627,
#        1.38312985, 1.38455389, 1.38735807, 1.38748357, 1.3885901 ,
#        1.39268135, 1.39288937, 1.39367725, 1.39748146, 1.39896647,
#        1.39973019, 1.3999569 , 1.40353043, 1.40554708, 1.40560803,
#        1.40755972, 1.40945556, 1.40917951, 1.41190778, 1.4145063 ,
#        1.41533304, 1.41490653, 1.41880447, 1.41907843, 1.42269756,
#        1.42401421, 1.42346619, 1.42355445, 1.42798097, 1.43095899,
#        1.42918439, 1.43237823, 1.43326783, 1.43509315, 1.43462465,
#        1.4378583 , 1.44057976, 1.44339594, 1.44186973, 1.44394874,
#        1.44511006, 1.44644747, 1.44498037, 1.44950868, 1.45054102,
#        1.45196591, 1.45418174, 1.45336427, 1.45531327, 1.45766255,
#        1.45810801, 1.46098081, 1.46128189, 1.46295466, 1.464062  ,
#        1.46514838, 1.46665429, 1.46930377, 1.47122685, 1.4704807 ,
#        1.4738603 , 1.47581703, 1.47534244, 1.47675518, 1.47965186,
#        1.47819641, 1.481991  , 1.48438663, 1.48566889, 1.48598341,
#        1.48684634, 1.48717374, 1.48971161, 1.49148149, 1.49290153,
#        1.49272846, 1.49725578, 1.49819433, 1.49739199, 1.50087338,
#        1.5005082 , 1.50032992, 1.5013567 , 1.5045569 , 1.50733332,
#        1.50602098, 1.50724653, 1.50921341, 1.50914163, 1.51212702,
#        1.51281654, 1.51301415, 1.51586796, 1.51593218, 1.51538549,
#        1.51935995, 1.52059376, 1.52004801, 1.52284993, 1.52414913,
#        1.52491572, 1.52378748, 1.5258704 , 1.52765821, 1.53082717,
#        1.53192642, 1.53266361, 1.5327487 , 1.53633638, 1.53527361,
#        1.53681545, 1.53776448, 1.54029365, 1.53956724, 1.54202866,
#        1.54266362, 1.54466223, 1.54693052, 1.54710299, 1.54674565,
#        1.5486937 , 1.54989956, 1.55287228, 1.55235685, 1.55289765,
#        1.55592444, 1.55566136, 1.55794186, 1.55780588, 1.5596639 ,
#        1.561115  , 1.56215444, 1.56180911, 1.56059051, 1.56304374,
#        1.56498894, 1.56643253, 1.56700711, 1.56799432, 1.57031538,
#        1.57090184, 1.57189266, 1.57275838, 1.5754844 , 1.57447879,
#        1.57549348, 1.57686208, 1.5791607 , 1.57861217, 1.57863481,
#        1.5809766 , 1.58197936, 1.58276983, 1.58325145, 1.58451157,
#        1.58657219, 1.58747699, 1.58803258, 1.58853351, 1.58923675,
#        1.59026194, 1.59300367, 1.59144232, 1.59417562, 1.59560367,
#        1.5972212 , 1.59701285, 1.59813286, 1.59951736, 1.60007379,
#        1.60147113, 1.60102227, 1.60328925, 1.6058512 , 1.60577715,
#        1.60570215, 1.6077221 , 1.60717266, 1.60903931, 1.61005326,
#        1.61116523, 1.60992962, 1.61264512, 1.61369601, 1.61306387,
#        1.61393603, 1.61565933, 1.61611782, 1.61824097, 1.61950966,
#        1.62025854, 1.62080564, 1.62164947, 1.62249173, 1.62271705,
#        1.62540498, 1.62474106, 1.62560586, 1.62695509, 1.6293682 ,
#        1.63013816, 1.63073561, 1.63202506, 1.63205692, 1.63251001,
#        1.63435624, 1.63650385, 1.63700586, 1.63732498, 1.63709008,
#        1.63875689, 1.6392389 , 1.63918667, 1.641235  , 1.64192516,
#        1.64250818, 1.64388372, 1.64415451, 1.64555467, 1.64490393,
#        1.644784  , 1.64692251, 1.64705693, 1.6496456 , 1.64886341,
#        1.65025107, 1.65144591, 1.65388362, 1.65268282, 1.65438261,
#        1.65584258, 1.65688445, 1.65735235, 1.6574284 , 1.65864088,
#        1.65980158, 1.65883246, 1.66008961, 1.66191615, 1.66179667,
#        1.66401507, 1.66305581, 1.6649631 , 1.66631609, 1.66690406,
#        1.66807383, 1.66732996, 1.66981099, 1.66971203, 1.67065988,
#        1.67237827, 1.67275293, 1.67295434, 1.67528617, 1.67658828,
#        1.67638343, 1.67738299, 1.6774573 , 1.67879762, 1.67841794,
#        1.68145126, 1.68100884, 1.68186816, 1.68308515, 1.68236701,
#        1.68448907, 1.68420268, 1.68669522, 1.688127  , 1.68829677,
#        1.68891732, 1.68960251, 1.69127927, 1.6898093 , 1.69051253,
#        1.69165143, 1.69294538, 1.69240076, 1.69389311, 1.6941988 ,
#        1.69430915, 1.69696815, 1.69572555, 1.69683271, 1.6979438 ,
#        1.69822135, 1.698019  , 1.69971261, 1.70090958, 1.70121504,
#        1.70334927, 1.70382545, 1.70456211, 1.70564992, 1.70575095,
#        1.70614822, 1.70685911, 1.70798196, 1.70846117, 1.71015645,
#        1.7100701 , 1.71054261, 1.71078853, 1.71208106, 1.71329311,
#        1.71208166, 1.7128797 , 1.71368391, 1.71609826, 1.71694265,
#        1.71753547, 1.71939977, 1.71701983, 1.720227  , 1.7188441 ,
#        1.7200423 , 1.72104721, 1.72186557, 1.7210781 , 1.72339044,
#        1.72266875, 1.72456955, 1.72536247, 1.72575073, 1.72689709,
#        1.72786609, 1.72737333, 1.72992005, 1.72967728, 1.73008643,
#        1.73088382, 1.7315028 , 1.73243314, 1.73354862, 1.73376721,
#        1.73395117, 1.73443598, 1.73526582, 1.73619794, 1.73630359,
#        1.73668458, 1.73665862, 1.73867619, 1.7405012 , 1.7385228 ,
#        1.7408534 , 1.7409128 , 1.74170984, 1.74290725, 1.7430584 ,
#        1.74374061, 1.74412245, 1.74401381, 1.74474041, 1.7456854 ,
#        1.74606411, 1.74722564, 1.7487102 , 1.74917834, 1.74875026,
#        1.7491214 , 1.75046821, 1.75025839, 1.75127307, 1.75268086,
#        1.75281096, 1.7525237 , 1.75297747, 1.75466753, 1.75294256,
#        1.75364621, 1.75564987, 1.75575004, 1.75567056, 1.75625282,
#        1.75691843, 1.75643183, 1.75785612, 1.75895538, 1.75988085,
#        1.76038591, 1.76090093, 1.76170663, 1.76140636, 1.76277976,
#        1.7631233 , 1.76363123, 1.76322333, 1.76478701, 1.76535776,
#        1.76643054, 1.76605816, 1.76601174, 1.76684575, 1.7669905 ,
#        1.76766743, 1.76761503, 1.76824056, 1.7698495 , 1.7702527 ,
#        1.77009422, 1.77136496, 1.77161353, 1.77203285, 1.77241989,
#        1.7733484 , 1.77285451, 1.77411137, 1.77465335, 1.7742282 ,
#        1.77510606, 1.77517261, 1.77580418, 1.77653079, 1.77639272,
#        1.77775601, 1.77811786, 1.77778329, 1.77887282, 1.77807399,
#        1.77758026, 1.78036043, 1.78040111, 1.78093122, 1.78249208,
#        1.78159475, 1.78289105, 1.78377981, 1.78406338, 1.78392074,
#        1.78406205, 1.78463539, 1.7857468 , 1.78537213, 1.78590954,
#        1.78643601, 1.78676734, 1.7864692 , 1.78676095, 1.78890917,
#        1.78847975, 1.78920713, 1.78983528, 1.79025576, 1.79067577,
#        1.79175108, 1.7910186 , 1.7916163 , 1.7927586 , 1.79389406,
#        1.79375088, 1.79426188, 1.79324494, 1.7942008 , 1.79486159,
#        1.795863  , 1.79664999, 1.79602043, 1.79695964, 1.79813056,
#        1.79731219, 1.79878809, 1.79832082, 1.79878856, 1.79891979,
#        1.79949735, 1.7998515 , 1.79926119, 1.80055998, 1.79999362,
#        1.80004501, 1.80037031, 1.80160743, 1.8018798 , 1.80156764,
#        1.80285054, 1.80292231, 1.80411755, 1.80423738, 1.80439919,
#        1.80555225, 1.80531875, 1.80635984, 1.80664068, 1.80713855,
#        1.80745161, 1.8078732 , 1.80791435, 1.80845848, 1.80807767,
#        1.8092011 , 1.80860565, 1.80902552, 1.80991883, 1.81053867,
#        1.81075121, 1.81194218, 1.81228718, 1.81221537, 1.81299563,
#        1.81376305, 1.81382283, 1.81508464, 1.81394682, 1.81458362,
#        1.8153003 , 1.81483781, 1.81484678, 1.81666479, 1.81688623,
#        1.81624219, 1.81703362, 1.81749456, 1.81796355])

# %%
linewidth = 2
plt.plot(arr_all, (Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[0], linewidth=linewidth)
plt.plot(arr_all, np.array(shot_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[0])
plt.plot(arr_all, (Pks_fof-shot_fof_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]), label=r"$\rm P_{S} (k=0.04)$", c=color_list[1])
plt.plot(arr_all, np.array(shot_fof_arr)/Pk_gal_all.attrs["shotnoise"], linestyle="dashed", label=r"P$_{\rm shot}$", c=color_list[1])
plt.xlim(10,10.5)
plt.ylim(0.9995,1.01)
plt.minorticks_on()
plt.xlabel('log$_{10}$(M$_\mathrm{min}$ [M$_\odot$ h$^{-1}$])')
plt.ylabel(r"$\rm P(k)/P(k)_{TNG\ all}$")


label_list = [r"$\rm M_{vir}$", r"$\rm M_{FOF}$"]
solid_lines=[]
for i in range(2):
    solid_line = Line2D([],[],color=color_list[i], linestyle="solid", label=label_list[i])
    solid_lines.append(solid_line)
bbox_to_anchor_grey = (0.5,0.33)
legend_fontsize=18
first_legend = plt.legend(handles=solid_lines,fontsize=legend_fontsize, frameon=False)
ax1 = plt.gca().add_artist(first_legend)
shotnoise_ps_leg = Line2D([],[],color="gray", linestyle="dashed", label=r"P$_{\rm shot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color="gray", label=r"$\rm P_{ S}(k=0.04)$")
leg_list = [shotnoise_subtracted_ps_leg, shotnoise_ps_leg]
plt.legend(handles=leg_list,bbox_to_anchor=bbox_to_anchor_grey,loc="upper left", fontsize=legend_fontsize, frameon=False)
plt.savefig("figures2/min_masses_zoomed.pdf", format="pdf", bbox_inches="tight")

# %%
plt.plot(arr_all, np.array(Pk_means)/Pk_mean_all)
plt.plot(arr_all, np.array(Pk_means_fof)/Pk_mean_all)

# %%
print(Pk_mean_all)
print(Pk_mean_gal10)
print(Pk_mean_105)
# Out:
# 12.871739713503061
# 12.855563459906872
# 12.773752621902833

# %%
interp="tsc"
Pk_shuffled_list = []
names_list = []
seed_i = 1
seed_f = 9
n_seed = seed_f - seed_i

power_list = []
odir = "ps_data"
snapnum=40
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap{snapnum}/shuffled/group/polyfit/ps-intensity-group-logM10_dlogM0.1_seed{seed}.pickle"
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled)
        
        #print("shotnoise", Pk_cent_shuffled.attrs["shotnoise"])
        Pk_shuffled_list.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")

power_arr = np.array(power_list)
# Out:
# 12.870028058594178
# 12.866583478727867
# 12.874466244228937
# 12.872212054142935
# 12.875102290975134
# 12.872073382669818
# 12.869196961784258
# 12.87260747509763

# %%
interp="tsc"
Pk_shuffled_list = []
names_list = []
seed_i = 1
seed_f = 9
n_seed = seed_f - seed_i

power_list = []
odir = "ps_data"
snapnum=40
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap{snapnum}/shuffled/cent/polyfit/ps-intensity-gal-logM10_dlogM0.1_seed{seed}.pickle"
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled)
        
        #print("shotnoise", Pk_cent_shuffled.attrs["shotnoise"])
        Pk_shuffled_list.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")

power_arr = np.array(power_list)
# Out:
# 9.298457719179893
# 9.307192229030123
# 9.30234206844252
# 9.299338867367831
# 9.307840901751781
# 9.305126657831117
# 9.306235161416302
# 9.303941588296402

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
fig,solid_leg = ps.compare_ps_plot([Pk_orig, Pk_shuffled], [r"original", r"shuffled"],  dim=3, residuals_only=False, bbox_to_anchor_grey=(0.4,-0.05), bbox_to_anchor_color=(-0.01,0.6), color_legend=True, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3), ratio_fontsize=26,  var=True)#, marker_size=1, linewidth=1)
plt.savefig("figures2/mvir_vs_mfof_logM10.pdf", format="pdf", bbox_inches="tight")
# Out:
# 344
# shotnoise:  7.882393312818058
# shotnoise:  7.882393312818058
# 0.011861365315160927 0.011828657988729131
# 0.011444577207009008 0.011411869880577212
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [0.4127171435006387, 0.38818522322237325, 0.3776027924520493, 0.2734762970726859, 0.37584808018141, 0.2122988559774097, 0.23131469576174649, 0.05424362677644881, 0.13634599009263926, 0.14665713827504304]
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1320: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
fig,solid_leg = ps.compare_ps_plot([Pk_gal_all, Pk_gal105,Pk_gal10, Pk_gal11], ["logM > 8", r"$ \rm logM_{min} = 10.5$", r"$ \rm logM_{min} = 10$", "logM>11"], ratio_ylabel_list = ["TNG\ all", ""], dim =3, residuals_only=True, bbox_to_anchor_grey=(0.5,0.3), bbox_to_anchor_color=(-0.01,0.6), color_legend=True, shotnoise_subtracted_ps = False, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3))#, ylim2=(0.95,1.07))#, marker_size=1, linewidth=1)

#ps.compare_ps_plot([Pk_gal_Nmesh4_interlaced, Pk_gal_tsc_not_interlaced, Pk_gal_tsc_interlaced],  labels=["Nmesh x 4", "No Interlacing", "Interlacing"], ratio_ylabel_list=["Nmesh \\times 2", " "], color_legend=True, residuals_only=True, total_ps=False, shotnoise_ps=False, xlim=(-1.6,1.9), bbox_to_anchor_grey=(0.37,0.7), bbox_to_anchor_color=(0.1,0.5), ncore=1, nyquist_list=[nyquist1], ylim2=(0.989,1.1))
Nmesh = 2247
boxsize = 204.9275
k_ny = np.pi * Nmesh / boxsize
log_k_ny = np.log10(k_ny/2)
#plt.axvline(x=log_k_ny, c='black', linestyle="dotted")
#plt.yticks([0,1,2])
#plt.savefig("figures2/tsc_interlace_vs_not.pdf", format="pdf", bbox_inches="tight")
ax = fig.axes[0]

#empty_leg = Line2D([0], [0],  lw=4, color="white")
#solid_leg.insert(1, empty_leg)

#ax.legend(handles=solid_leg[1:], loc='upper center', bbox_to_anchor=(0.5, 1.2),
 #         fancybox=True, shadow=True, ncol=2)

#plt.savefig("figures2/min_mass_ps_ratio_mvir.pdf", format="pdf", bbox_inches="tight")
# Out:
# 344
# shotnoise:  134.30755917292575
# shotnoise:  136.3740204110012
# shotnoise:  134.64551712053182
# shotnoise:  145.03438832759022
# 0.04400589489614298 0.04344859700376513
# 0.04430132132330441 0.04373544882425697
# 0.04403021785321751 0.04347151763283166
# 0.045496348052730506 0.04489454008722941
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [1.0154156095125386, 1.0154543749189755, 1.0154098767734707, 1.015433423262854, 1.0154482328266374, 1.0154420851557673, 1.0154186696831702, 1.0154238480359588, 1.0154166735435555, 1.0154310816230272]
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [1.0025422593370772, 1.002547904923122, 1.0025475123849859, 1.002545599046489, 1.0025554972592055, 1.0025466731666046, 1.0025458893711319, 1.0025480928454529, 1.0025503087324812, 1.0025482213830788]
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [1.0796644468303924, 1.0798851988413083, 1.0799344421558388, 1.0798687085042187, 1.079709207217179, 1.0798824152042426, 1.0799647952939988, 1.0799864430324375, 1.0798159455235785, 1.07996448591326]

# %%
Pk_list = [Pk_group10]
Pk_list.extend(power_list)

# %%
fig,solid_leg = ps.compare_ps_plot(Pk_gal10)#, ratio_ylabel_list=["TNG", "Shuffled"], residuals_only=False, bbox_to_anchor_grey=(0.5,0.5), bbox_to_anchor_color=(0.1,0.55), color_legend=False, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3), ylim2=(0.88,1.05))# ylim1=(0.9,1.1))

plt.savefig("figures2/shuffled_minus_polyfit_seeds1-9.pdf", format="pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cbc570074423> in <module>()
# ----> 1 fig,solid_leg = ps.compare_ps_plot(Pk_gal10)#, ratio_ylabel_list=["TNG", "Shuffled"], residuals_only=False, bbox_to_anchor_grey=(0.5,0.5), bbox_to_anchor_color=(0.1,0.55), color_legend=False, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3), ylim2=(0.88,1.05))# ylim1=(0.9,1.1))
#       2
#       3 plt.savefig("figures2/shuffled_minus_polyfit_seeds1-9.pdf", format="pdf", bbox_inches="tight")
#
# ~/MyHaloPS.py in compare_ps_plot(Pks, labels, ratio_ylabel_list, mean, var, log, dim, others, noise, fontsize, ratio_fontsize, color_legend, grey_legend, legend_fontsize, ylim1, ylim2, ylim3, error_band, shotnoise_ps, shotnoise_subtracted_ps, xlim, grey_shading, residuals_only, separate_ratio_panels, bbox_to_anchor_grey, bbox_to_anchor_color, marker_size, ncore, nyquist_list, total_ps, len_k, knyq, return_solid_leg, start_k, mean_of_seeds, linewidth)
#    1186                 else:
#    1187                         len_k = len(Pks[0]["k"])
# -> 1188         logk = np.log10(Pks[0]['k'][:len_k])
#    1189         k_coef = Pks[0]["k"][:len_k]**3 / (2 * np.pi**2)
#    1190
#
# ~/.local/lib/python3.6/site-packages/nbodykit/binned_statistic.py in __getitem__(self, key)
#     354
#     355         # indices to slice the data with
# --> 356         indices = [list(range(0, self.shape[i])) for i in range(len(self.dims))]
#     357
#     358         # check for list/tuple of variable names
#
# ~/.local/lib/python3.6/site-packages/nbodykit/binned_statistic.py in <listcomp>(.0)
#     354
#     355         # indices to slice the data with
# --> 356         indices = [list(range(0, self.shape[i])) for i in range(len(self.dims))]
#     357
#     358         # check for list/tuple of variable names
#
# ~/.local/lib/python3.6/site-packages/nbodykit/binned_statistic.py in shape(self)
#     202         The shape of the coordinate grid
#     203         """
# --> 204         return tuple(len(self.coords[d]) for d in self.dims)
#     205
#     206     @property
#
# ~/.local/lib/python3.6/site-packages/nbodykit/binned_statistic.py in <genexpr>(.0)
#     202         The shape of the coordinate grid
#     203         """
# --> 204         return tuple(len(self.coords[d]) for d in self.dims)
#     205
#     206     @property
#
# TypeError: list indices must be integers or slices, not str

# %%
Pk_gals_arr = np.array(Pk_gals)

# %%
Pk_list = [Pk_gal10]

# %%
Pk_list.extend(Pk_gals)

# %%
ps.compare_ps_plot(Pk_list, labels=["TNG", "shuffled"], ratio_ylabel_list=["TNG", "Shuffled"],ncore=1, var=True, color_legend=True, mean_of_seeds=True, bbox_to_anchor_color=(0.7,0.3), bbox_to_anchor_grey=(0.5,0.5), ylim2=(0.88,1.05))
plt.savefig("figures2/shuffled_minus_polyfit_seeds1-9_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# 344
# shotnoise:  267.7301748422947
# shotnoise:  267.97399738052263
# 0.04401099688201283 0.042900073095709354
# 0.039587426449618 0.03847549094225053
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [0.12068730126357037, 1.0973249213980805, 1.1862632816582055, 0.08684031555968823, 0.2633831888627799, 0.48186698384515614, 2.119278783198467, 0.5002795890525661, 2.016863265781695, 0.7789656633015254]
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1320: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
fig,solid_leg = ps.compare_ps_plot([Pk_gal_all100, Pk_gal105, Pk_gal10], ["TNG300-1", "logM > 10.5", "logM > 10"], residuals_only=True, bbox_to_anchor_grey=(0.6,0.3), bbox_to_anchor_color=(0,0.55), color_legend=False, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3))# ylim1=(0.9,1.1))
#ps.compare_ps_plot([Pk_gal_Nmesh4_interlaced, Pk_gal_tsc_not_interlaced, Pk_gal_tsc_interlaced],  labels=["Nmesh x 4", "No Interlacing", "Interlacing"], ratio_ylabel_list=["Nmesh \\times 2", " "], color_legend=True, residuals_only=True, total_ps=False, shotnoise_ps=False, xlim=(-1.6,1.9), bbox_to_anchor_grey=(0.37,0.7), bbox_to_anchor_color=(0.1,0.5), ncore=1, nyquist_list=[nyquist1], ylim2=(0.989,1.1))
Nmesh = 2247
boxsize = 204.9275
k_ny = np.pi * Nmesh / boxsize
log_k_ny = np.log10(k_ny/2)
#plt.axvline(x=log_k_ny, c='black', linestyle="dotted")
#plt.yticks(np.arange(0.7, 1.3, 0.1))
#plt.savefig("figures2/tsc_interlace_vs_not.pdf", format="pdf", bbox_inches="tight")
ax = fig.axes[0]

#empty_leg = Line2D([0], [0],  lw=4, color="white")
#solid_leg.insert(1, empty_leg)

ax.legend(handles=solid_leg[1:], loc='upper center', bbox_to_anchor=(0.5, 1.2),
          fancybox=True, shadow=True, ncol=2)

#plt.savefig("figures2/logM10.5_cent_vs_sat.pdf", format="pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c97e8287e7a6> in <module>()
# ----> 1 fig,solid_leg = ps.compare_ps_plot([Pk_gal_all100, Pk_gal105, Pk_gal10], ["TNG300-1", "logM > 10.5", "logM > 10"], residuals_only=True, bbox_to_anchor_grey=(0.6,0.3), bbox_to_anchor_color=(0,0.55), color_legend=False, ncore=1, return_solid_leg=True, xlim=(-1.55, 1.3))# ylim1=(0.9,1.1))
#       2 #ps.compare_ps_plot([Pk_gal_Nmesh4_interlaced, Pk_gal_tsc_not_interlaced, Pk_gal_tsc_interlaced],  labels=["Nmesh x 4", "No Interlacing", "Interlacing"], ratio_ylabel_list=["Nmesh \\times 2", " "], color_legend=True, residuals_only=True, total_ps=False, shotnoise_ps=False, xlim=(-1.6,1.9), bbox_to_anchor_grey=(0.37,0.7), bbox_to_anchor_color=(0.1,0.5), ncore=1, nyquist_list=[nyquist1], ylim2=(0.989,1.1))
#       3 Nmesh = 2247
#       4 boxsize = 204.9275
#       5 k_ny = np.pi * Nmesh / boxsize
#
# NameError: name 'Pk_gal_all100' is not defined
