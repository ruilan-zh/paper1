# %%
import numpy as np
import cProfile
import MyShuffle as shuffle
import importlib
importlib.reload(shuffle)
# Out:
# <module 'MyShuffle' from '/cosma/home/dp004/dc-zhan5/paper1/shuffle_sfrs/MyShuffle.py'>

# %%
shuffler = shuffle.Shuffler(ps_type="gal", object2shuffle="gal",include_bh=True, include_conc=True)

# %%
cProfile.runctx(shuffler.shuffle_in_bins(),globals(),locals())
# Out:
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_central.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-cent_0sfr.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_satellite.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_satellite_relative.txt
# 0.1
# 70
# Shuffling halos done
# Shuffling satellites
# Total number of satellites in box: 569701
# Number of satellites shuffled: 569701
# Nsat outside of box: 708
# Written to  /cosma8/data/dp004/dc-zhan5/shuffled/logM10_dlogM0.1_snap40/changed_bins/gal_ps/shuffle_gal/////seed0.txt
#          2 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
# ...

# %%
cProfile.run("shuffler.shuffle_in_bins()")
# Out:
# Shuffling halos done
# Shuffling satellites
# Total number of satellites in box: 569701
# Number of satellites shuffled: 569701
# Nsat outside of box: 708
# Written to  /cosma8/data/dp004/dc-zhan5/shuffled/logM10_dlogM0.1_snap40/changed_bins/gal_ps/shuffle_gal/////seed0.txt
#          8351990 function calls (8351778 primitive calls) in 15.816 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        42    0.000    0.000    0.189    0.004 <__array_function__ internals>:2(argsort)
#        68    0.000    0.000    0.026    0.000 <__array_function__ internals>:2(concatenate)
#        34    0.000    0.000    0.072    0.002 <__array_function__ internals>:2(cumsum)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        42    0.000    0.000    1.125    0.027 <__array_function__ internals>:2(in1d)
# ...

# %%
shuffler.bin_data()
# Out:
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_central.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-cent_0sfr.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_satellite.txt
# Reading /cosma7/data/dp004/dc-zhan5/TNG/snap40/SubhaloFlag_all/mvir/ihalo/bh_mass/sfr-halomass_satellite_relative.txt
# 0.1
# 70

# %%
cProfile.run("shuffler.shuffle_in_bins()")
# Out:
# Shuffling halos done
# Shuffling satellites
# Total number of satellites in box: 569701
# Number of satellites shuffled: 569701
# Nsat outside of box: 708
#          7280262 function calls (7280050 primitive calls) in 8.713 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        42    0.000    0.000    0.186    0.004 <__array_function__ internals>:2(argsort)
#        68    0.000    0.000    0.025    0.000 <__array_function__ internals>:2(concatenate)
#        34    0.000    0.000    0.073    0.002 <__array_function__ internals>:2(cumsum)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        42    0.000    0.000    1.104    0.026 <__array_function__ internals>:2(in1d)
#        42    0.000    0.000    1.105    0.026 <__array_function__ internals>:2(isin)
#        42    0.000    0.000    0.014    0.000 <__array_function__ internals>:2(searchsorted)
# ...
