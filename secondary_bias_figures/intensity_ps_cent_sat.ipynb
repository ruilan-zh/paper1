# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rc("font", family="STIXGeneral", size=18)
plt.rcParams["mathtext.fontset"] = "stix"
plt.rcParams['figure.figsize'] = (2*10/3, 4)
plt.rcParams["legend.frameon"] = False


plt.rcParams["xtick.major.size"] = 5
plt.rcParams["ytick.major.size"] = 5
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["lines.linewidth"] = 2

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.5236074519707

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.5236074519707

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sat_logM10.pickle", "rb") as f:
    Pk_mean_sat10 = pickle.load(f)
    Pk_sat10 = pickle.load(f)
print("shotnoise", Pk_sat10.attrs["shotnoise"])
# Out:
# shotnoise 352.60039701132393

# %%
logM_names = ["logMmax11", "logM11-11.5", "logM11.5-12", "logM12-12.5", "logM12.5-13", "logMmin13"]

# %%
logM_names = [""]

# %%
object2shuffle = "cent"
interp="tsc"
Pk_shuffled_list_cents = []

for logM_name in logM_names:
    Pk_shuffled_list = []
    names_list = []
    seed_i = 0
    seed_f = 100
    n_seed = seed_f - seed_i

    power_list = []
    mean_intensities = []
    odir = "ps_data"
    snapnum=40

    for seed in range(seed_i,seed_f):
        fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/cent_ps/shuffle_{object2shuffle}/{logM_name}/seed{seed}.pickle"
        
        if seed == 0:
            print(fname)
        with open(fname, "rb") as f:
            Pk_mean_gal_shuffled = pickle.load(f)
            #print("mean", Pk_mean_cent_shuffled)
            Pk_gal_shuffled = pickle.load(f)
            #print(Pk_mean_gal_shuffled)
            power_list.append(Pk_gal_shuffled["power"].real)

            mean_intensities.append(Pk_mean_gal_shuffled)

            print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
            Pk_shuffled_list.append(Pk_gal_shuffled)
            names_list.append(f"seed{seed}")


    power_arr = np.array(power_list)
    Pk_shuffled_list_cents.append(Pk_shuffled_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/cent_ps/shuffle_cent//seed0.pickle
# shotnoise 202.34259177562296
# shotnoise 202.34259177562296
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.34259177562296
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.342591775623
# shotnoise 202.342591775623
# shotnoise 202.342591775623
# shotnoise 202.34259177562308
# shotnoise 202.34259177562305
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.34259177562296
# shotnoise 202.34259177562308
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.34259177562308
# shotnoise 202.34259177562294
# shotnoise 202.34259177562296
# shotnoise 202.34259177562308
# shotnoise 202.34259177562296
# shotnoise 202.34259177562288
# shotnoise 202.34259177562288
# shotnoise 202.34259177562296
# shotnoise 202.34259177562294
# ...

# %%
object2shuffle = "sat"
interp="tsc"
Pk_shuffled_list_sats = []

for logM_name in logM_names:
    Pk_shuffled_list = []
    names_list = []
    seed_i = 0
    seed_f = 100
    n_seed = seed_f - seed_i

    power_list = []
    mean_intensities = []
    odir = "ps_data"
    snapnum=40

    for seed in range(seed_i,seed_f):
        #fname = f"{odir}/snap40/mvir/2d/{slice_width}slice/shuffled_in_slice/logM10_zslice{islice}/seed{seed}.pickle"
        fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/sat_ps/shuffle_{object2shuffle}/{logM_name}/seed{seed}.pickle"
        
        if seed == 0:
            print(fname)
        with open(fname, "rb") as f:
            Pk_mean_gal_shuffled = pickle.load(f)
            #print("mean", Pk_mean_cent_shuffled)
            Pk_gal_shuffled = pickle.load(f)
            #print(Pk_mean_gal_shuffled)
            power_list.append(Pk_gal_shuffled["power"].real)

            mean_intensities.append(Pk_mean_gal_shuffled)

            print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
            Pk_shuffled_list.append(Pk_gal_shuffled)
            names_list.append(f"seed{seed}")


    power_arr = np.array(power_list)
    Pk_shuffled_list_sats.append(Pk_shuffled_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/sat_ps/shuffle_sat//seed0.pickle
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# shotnoise 352.6003970113244
# ...

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
fig, axs = plt.subplots(3, 2, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*2*10/3, 5))
for i, logM_name in enumerate(logM_names):
    color_leg1 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i%3][i//3], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[2:3], same_color=True)
    color_leg2 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i%3][i//3], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[4:5], same_color=True)
    
    axs[i%3][i//3].set_ylim(0.955,1.06)
    if i == 0:
        logM_name = "logM < 11"
    if i == 5:
        logM_name = "logM > 13"
    axs[i%3][i//3].annotate(f"{logM_name}", (0.4,1.03)) 
#axs[1].annotate(r"$\rm P(k)/\bar{P}(k)_{Shuffled}$", (0, 0.55), xycoords='figure fraction', rotation=90, fontsize=18, va="center")
leg = axs[0][0].legend(handles=color_leg1 , labels=["Centrals"], loc='upper left', bbox_to_anchor=(0, 1))
axs[0][0].add_artist(leg)
leg = axs[0][0].legend(handles= color_leg2, labels=["Satellites"], loc='lower left', bbox_to_anchor=(0, -0.05))
axs[0][0].add_artist(leg)



#ax.annotate("Shuffling", (0.25,1.06))
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = axs[0][0].legend(handles=[solid_line], labels=[r"$P(k)_{\rmTNG}/\bar{P}(k)_{\rmShuffled}$"],loc='lower left', bbox_to_anchor=(0.3, 1))
axs[0][0].add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
axs[0][1].legend(handles=[dot_line], labels=[r"5 - 95% $(P(k)_{\rm Shuffled}/\bar{P}(k)_{\rm Shuffled})$"],  loc='lower right', bbox_to_anchor=(0.7, 1))

#axs[0][2].set_ylabel(r"$P(k)/\bar{P}(k)_{\rm Shuffled}$")
#plt.legend()
#plt.savefig("figures/cent_vs_sat_shuffled_ps_logM.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197058
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197066
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197063
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197055
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0

# %%
fig, axs = plt.subplots(6, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 12.5))
for i, logM_name in enumerate(logM_names):
    color_leg1 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[2:3], same_color=True)
    color_leg2 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[4:5], same_color=True)
    
    axs[i].set_ylim(0.955,1.06)
    if i == 5:
        logM_name = "logM > 13.5"
    axs[i].annotate(f"{logM_name}", (0.4,1.03)) 
#axs[1].annotate(r"$\rm P(k)/\bar{P}(k)_{Shuffled}$", (0, 0.55), xycoords='figure fraction', rotation=90, fontsize=18, va="center")
leg = axs[1].legend(handles=color_leg1 + color_leg2, labels=["Centrals", "Satellites"], loc='upper left', bbox_to_anchor=(0, 1))
axs[1].add_artist(leg)

#ax.annotate("Shuffling", (0.25,1.06))
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = axs[0].legend(handles=[solid_line], labels=[r"$P(k)_{\rmTNG}/\bar{P}(k)_{\rmShuffled}$"], loc='upper left', bbox_to_anchor=(0, 1))
axs[0].add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
axs[0].legend(handles=[dot_line], labels=[r"5 - 95% $(P(k)_{\rm Shuffled}/\bar{P}(k)_{\rm Shuffled})$"], loc='lower left', bbox_to_anchor=(0, 0))

axs[2].set_ylabel(r"$P(k)/\bar{P}(k)_{\rm Shuffled}$")
#plt.legend()
#plt.savefig("figures/cent_vs_sat_shuffled_ps_logM.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197066
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197063
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197055
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.5236074519707
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.5236074519707
# shotnoise:  130.5236074519707
# 0
# Text(0, 0.5, '$P(k)/\\bar{P}(k)_{\\rm Shuffled}$')

# %%
fig, axs = plt.subplots(4, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 10))
for i, logM_name in enumerate(logM_names):
    color_leg1 = ps.residual_plot([Pk_cent10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[2:3], same_color=True)
    color_leg2 = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=axs[i], return_color_leg=True, remove_ylabel=True, color_list=palette_tab10[4:5], same_color=True)
    
    axs[i].set_ylim(0.93,1.11)
    if i == 4:
        logM_name = "logM > 13"
    axs[i].annotate(f"{logM_name}", (0.4,1.03)) 
axs[1].annotate(r"$\rm P(k)/\overline{P}(k)_{Random}$", (0, 0.55), xycoords='figure fraction', rotation=90, fontsize=18, va="center")
fig.legend(handles=color_leg1 + color_leg2, labels=["Centrals", "Satellites"], loc='upper left', bbox_to_anchor=(0.15, 0.89))
#plt.legend()
#plt.savefig("figures/shuffled_cent_sat_ps_logM.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  202.34259177562322
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132393
# 0
# is list
# shotnoise:  202.34259177562294
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.60039701132416
# shotnoise:  352.60039701132393
# 0
# is list
# shotnoise:  202.34259177562282
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.60039701132416
# shotnoise:  352.60039701132393
# 0
# is list
# shotnoise:  202.34259177562285
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.6003970113239
# shotnoise:  352.60039701132393
# 0

# %%
i = 3

fig, ax = plt.subplots(1, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 4))
color_leg1 = ps.residual_plot([Pk_cent10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[2:3], same_color=True)
color_leg2 = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[4:5], same_color=True)
fig.legend(handles=color_leg1 + color_leg2, labels=["Centrals", "Satellites"], loc='upper left', bbox_to_anchor=(0.6, 0.89))
print(logM_names[i])
plt.savefig(f"figures/shuffled_cent_sat_ps_{logM_names[i]}.pdf", format="pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-d75ef5e555fc> in <module>()
#       2
#       3 fig, ax = plt.subplots(1, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 4))
# ----> 4 color_leg1 = ps.residual_plot([Pk_cent10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[2:3], same_color=True)
#       5 color_leg2 = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Random",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[4:5], same_color=True)
# ...

# %%
i = 0

fig, ax = plt.subplots(1, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 4))
color_leg1 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[2:3], same_color=True)
color_leg2 = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[4:5], same_color=True)
leg = ax.legend(handles=color_leg1 + color_leg2, labels=["Centrals", "Satellites"], loc='upper right', bbox_to_anchor=(1, 0.7))
ax.add_artist(leg)
print(logM_names[i])

ax.annotate("Shuffling", (0.25,1.06))
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P(k)_{\rmTNG}/\bar{P}(k)_{\rmShuffled}$"], loc='upper left', bbox_to_anchor=(0.05, 1.03))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P(k)_{\rm Shuffled}/\bar{P}(k)_{\rm Shuffled})$"], loc='lower right', bbox_to_anchor=(1, 0))


#plt.savefig(f"figures/cent_vs_sat_shuffled_gal_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# is list
# shotnoise:  130.5236074519708
# shotnoise:  130.5236074519707
# 0

# %%
i = 0

fig, ax = plt.subplots(1, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 4))
color_leg1 = ps.residual_plot([Pk_cent10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[2:3], same_color=True)
color_leg2 = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[4:5], same_color=True)
leg = ax.legend(handles=color_leg1 + color_leg2, labels=["Central P(k)", "Satellite P(k)"], loc='upper right', bbox_to_anchor=(1, 0.8))
ax.add_artist(leg)
print(logM_names[i])

solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P(k)_{\rmTNG}/\bar{P}(k)_{\rmShuffled}$"], loc='upper right', bbox_to_anchor=(1, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P(k)_{\rm Shuffled}/\bar{P}(k)_{\rm Shuffled})$"], loc='lower right', bbox_to_anchor=(1, 0))


#plt.savefig(f"figures/shuffled_cent_sat_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  202.34259177562296
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132393
# 0

# %%
import matplotlib.ticker as ticker

# %%
i = 0

fig, ax = plt.subplots(1, 1, sharex=True, gridspec_kw={'hspace': 0}, figsize=(2*10/3, 4))
color_leg1 = ps.residual_plot([Pk_cent10], mean_of_seeds_lists=[Pk_shuffled_list_cents[i]], percentiles=[25, 5], labels=["Centrals" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[2:3], same_color=True)
color_leg2 = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list_sats[i]], percentiles=[25, 5], labels=["Satellites" ], ratio_ylabel_list=["Shuffled",""], create_fig=False, ax=ax, return_color_leg=True, remove_ylabel=False, color_list=palette_tab10[4:5], same_color=True)
leg = ax.legend(handles=color_leg1 + color_leg2, labels=["Central P(k)", "Satellite P(k)"], loc='upper right', bbox_to_anchor=(1, 0.8))
ax.add_artist(leg)
print(logM_names[i])

solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P(k)_{\rmTNG}/\bar{P}(k)_{\rmShuffled}$"], loc='upper right', bbox_to_anchor=(1, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P(k)_{\rm Shuffled}/\bar{P}(k)_{\rm Shuffled})$"], loc='lower right', bbox_to_anchor=(1, 0))
ax = plt.gca()
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

#plt.savefig(f"figures/shuffled_cent_sat_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  202.34259177562296
# shotnoise:  202.34259177562294
# 0
# is list
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132393
# 0
