# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle
# Out:
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:495: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_ylabel("log$_{10}$($k^3$ P(k) / $2 \pi^2$)", fontsize=fontsize)
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:596: SyntaxWarning: invalid escape sequence '\o'
#   label = "$M_h =$" + f"$10^{{{exp}}}$" + " $M_\odot h^{-1}$"
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:671: SyntaxWarning: invalid escape sequence '\o'
#   leg = ax.legend(handles1[:i], labels1[:i], title="Halo mass $[M_\odot h^{-1}]$", handlelength=0,
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:709: SyntaxWarning: invalid escape sequence '\p'
#   """
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:938: SyntaxWarning: invalid escape sequence '\ '
#   """
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1203: SyntaxWarning: invalid escape sequence '\m'
#   units = "[$\mathrm{Jy^2 sr^{-2}}$]"
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1206: SyntaxWarning: invalid escape sequence '\ '
#   units = "\ \mathrm{[h^{-3}Mpc^3]}"

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group1 = pickle.load(f)

# %%
random_list = []
for iseed in range(3):
    fname = f"{odir}/weight1_5_random_seed{iseed}.pickle"
    with open(fname, "rb") as f:
        Pk_mean_group10 = pickle.load(f)
        Pk_group12 = pickle.load(f)
        random_list.append(Pk_group12)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1_5_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight5_1_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_reverse = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1(25)_5(75)_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_per = pickle.load(f)

# %%
fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (\\tilde{c}<\\tilde{c}_{50}), W=5\ (\\tilde{c}>\\tilde{c}_{50}) $", "$W=1\ (\\tilde{c}>\\tilde{c}_{50}), W=5\ (\\tilde{c}<\\tilde{c}_{50})$",  "$W=1\ (50\%), W=5\ (50\%)$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()
ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.75))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.95))
ax.add_artist(leg1)

leg0 = ax.legend(handles=[color_leg[1]], loc="upper left", bbox_to_anchor=(0.38,0.6), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg0)
leg1 = ax.legend(handles=[color_leg[3]], loc="upper left", bbox_to_anchor=(0.38,0.5), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
leg1 = ax.legend(handles=[color_leg[2]], loc="upper left", bbox_to_anchor=(0.38,0.4), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.85,1.5)
#plt.savefig("../figures/sec3_2nd_bias.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  193.40273880345717
# shotnoise:  279.3620845014718
# shotnoise:  279.3620845014718
# shotnoise:  279.3569387373952
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_2211702/3011456159.py:1: SyntaxWarning: invalid escape sequence '\ '
# ...

# %%
fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (\\tilde{c}<\\tilde{c}_{50}), W=5\ (\\tilde{c}>\\tilde{c}_{50}) $", "$W=1\ (\\tilde{c}>\\tilde{c}_{50}), W=5\ (\\tilde{c}<\\tilde{c}_{50})$",  "$W=1\ (50\%), W=5\ (50\%)$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True, color_list=["dodgerblue", palette_tab10[1],"navy","crimson"], shotnoise_subtracted_ps_len_k=8)#, ylim1=(0.9,1.4))
ax = plt.gca()
#ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")
ax.annotate(r"$\mathbf{log}\, \boldsymbol{M}_\boldsymbol{h} \boldsymbol{\sim 11}$", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.75))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.95))
ax.add_artist(leg1)
leg1 = ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.4,0.2), handletextpad=0)
ax.add_artist(leg1)

leg0 = ax.legend(handles=[color_leg[1]], loc="upper left", bbox_to_anchor=(0.38,0.6), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg0)
leg1 = ax.legend(handles=[color_leg[3]], loc="upper left", bbox_to_anchor=(0.38,0.5), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
leg1 = ax.legend(handles=[color_leg[2]], loc="upper left", bbox_to_anchor=(0.38,0.4), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.85,1.5)
#plt.savefig("../figures/sec3_2nd_bias.pdf", format="pdf", bbox_inches="tight")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2211702/2835873403.py:1: SyntaxWarning: invalid escape sequence '\ '
# ...
