# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "../../nbodykit-ps/ps_data_sphereX_res"
with open(f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group10 = pickle.load(f)

# %%
fname = f"{odir}/snap40/mvir/invented/sigma0/seed0.pickle"
#fname = f"{odir}/snap40/mvir/invented/sigma0.pickle"
sigma=0
seed=0
fname = f"{odir}/snap40/mvir/assignment_schemes/gaussian/tng_linear_mean/changed_sfr_func/nonzero/sigma={sigma}/seed{seed}.pickle"
   
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk10 = pickle.load(f)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group10, Pk10], len_k=30, grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"TNG", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\mathrm{TNG}", r"\overline{L}(M)"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True, color_list=palette_tab10[1:2] + ["crimson"])#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.65,0.35))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.3))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.7,0.9))
#plt.savefig("../figures/tng_vs_mean_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  303.7679168819035
# shotnoise:  178.3851769132499
