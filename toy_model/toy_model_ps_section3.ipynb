# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.5"
fname = f"{odir}/weight1.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group1 = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.5"


random_list = []
for iseed in range(5):
    fname = f"{odir}/weight1_10_random_seed{iseed}.pickle"
    with open(fname, "rb") as f:
        Pk_mean_group10 = pickle.load(f)
        Pk_group12 = pickle.load(f)
        random_list.append(Pk_group12)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.5"
fname = f"{odir}/weight1_10_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.5"
fname = f"{odir}/weight10_1_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_reverse = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.5"
fname = f"{odir}/weight1(25)_10(75)_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_per = pickle.load(f)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12, Pk_group12_cprox, Pk_group12_cprox_reverse, Pk_group12_cprox_per], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W", ""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  55.4683677148523
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  135.22465975455117
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2822752/3286666775.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12, Pk_group12_cprox, Pk_group12_cprox_reverse, Pk_group12_cprox_per], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W", ""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1502: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.8, 1.8)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12, Pk_group12_cprox, Pk_group12_cprox_reverse], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  55.4683677148523
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_1528096/3145276889.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12, Pk_group12_cprox, Pk_group12_cprox_reverse], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# (0.8, 1.8)

# %%
lbls = [""]*len(random_list)
fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse, *random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W", *lbls], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  55.4683677148523
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_1528096/3057785628.py:2: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse, *random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W", *lbls], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# (0.8, 1.8)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)

#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  55.4683677148523
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2822752/455999650.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1502: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.8, 1.8)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2249116/634412649.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1502: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
plt.ylim(0.9,1.5)
# Out:
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2249116/2029756946.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1502: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.9, 1.5)

# %%
ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=False, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
# Out:
# shotnoise:  92.6000849454559
# shotnoise:  92.6000849454559
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2249116/3209606456.py:1: SyntaxWarning: invalid escape sequence '\m'
#   ps.compare_ps_plot([Pk_group12, Pk_group12_cprox], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", "High bias = High weight"], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=False, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.4), toy_model=True)#, ylim1=(0.9,1.4))
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1502: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# /tmp/ipykernel_2249116/3209606456.py:1: SyntaxWarning: invalid escape sequence '\m'
# ...
