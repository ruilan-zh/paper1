# %% [markdown]
# # 3D halo power spectrum

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle
# Out:
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:495: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_ylabel("log$_{10}$($k^3$ P(k) / $2 \pi^2$)", fontsize=fontsize)
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:596: SyntaxWarning: invalid escape sequence '\o'
#   label = "$M_h =$" + f"$10^{{{exp}}}$" + " $M_\odot h^{-1}$"
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:671: SyntaxWarning: invalid escape sequence '\o'
#   leg = ax.legend(handles1[:i], labels1[:i], title="Halo mass $[M_\odot h^{-1}]$", handlelength=0,
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:709: SyntaxWarning: invalid escape sequence '\p'
#   """
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:938: SyntaxWarning: invalid escape sequence '\ '
#   """
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1203: SyntaxWarning: invalid escape sequence '\m'
#   units = "[$\mathrm{Jy^2 sr^{-2}}$]"
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1206: SyntaxWarning: invalid escape sequence '\ '
#   units = "\ \mathrm{[h^{-3}Mpc^3]}"

# %%
odir = "../../nbodykit-ps/ps_data_sphereX_res"
fname = f"{odir}/snap40/mvir/invented/sigma0/seed0.pickle"
#fname = f"{odir}/snap40/mvir/invented/sigma0.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group10_invented = pickle.load(f)

# %%
sigma=0.2
odir = "../../nbodykit-ps/ps_data_sphereX_res"
Pk_gaussian_list = []
Pk_gaussian_list_mean = []
names_list = []
seed_i = 0
seed_f = 5
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
#odir = "ps_data"
snapnum=40
for seed in range(seed_i,seed_f):
    #fname = f"{odir}/snap40/mvir/invented/2sigma/0.4_0.2/seed{seed}.pickle"
    #fname = f"{odir}/snap40/mvir/invented/2sigma/linear_sigma/sigma=mean_divided_by_5_3/seed{seed}.pickle"
    fname = f"{odir}/snap40/mvir/invented/sigma{sigma}/seed{seed}.pickle"
  

    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        #print("shotnoise", Pk_cent_shuffled.attrs["shotnoise"])
        Pk_gaussian_list.append(Pk_gal_shuffled)
        Pk_gaussian_list_mean.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")

power_arr = np.array(power_list)

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
fname = f"{odir}/snap40/mvir/invented/sigma0/seed0.pickle"
   
with open(fname, "rb") as f:
    Pk_mean_group0 = pickle.load(f)
    Pk_group0 = pickle.load(f)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.2"], dim=3, residuals_only=False, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_877364/2507265111.py:1: SyntaxWarning: invalid escape sequence '\s'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.2"], dim=3, residuals_only=False, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877364/2507265111.py:1: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_877364/302229744.py:1: SyntaxWarning: invalid escape sequence '\s'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877364/302229744.py:1: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
sigma=0.2
odir = "../../nbodykit-ps/ps_data_sphereX_res"
Pk_gaussian_list = []
Pk_gaussian_list_mean = []
names_list = []
seed_i = 0
seed_f = 5
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
#odir = "ps_data"
snapnum=40
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/invented/2sigma/0.4_0.2/seed{seed}.pickle"
   

    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        #print("shotnoise", Pk_cent_shuffled.attrs["shotnoise"])
        Pk_gaussian_list.append(Pk_gal_shuffled)
        Pk_gaussian_list_mean.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")

power_arr = np.array(power_list)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.4,0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
#plt.savefig("../figures/invented_sigma=0.4_0.2_ps_ratio_orig_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  84.60423087309721
# shotnoise:  98.68026681304815
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_877364/1741365112.py:1: SyntaxWarning: invalid escape sequence '\s'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.4,0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877364/1741365112.py:1: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 3))
grey_leg = ps.residual_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list],   percentiles=[25], ratio_ylabel_list=[r"\sigma = 0", r"\sigma = 0.4,0.2", ""], mean_of_seeds_reverse=True, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True, color_list=["DodgerBlue", "Crimson"])
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.95))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.55))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))

#plt.savefig("../figures/invented_sigma=0.4_0.2_ps_ratio_orig_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  84.60423087309721
# shotnoise:  98.68026681304815

# %%
Pk_new_means = []
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/invented/2sigma/0.4_0.2/mean/seed{seed}.pickle"

    with open(fname, "rb") as f:
        Pk_mean_group0_linear = pickle.load(f)
        Pk_group0_linear = pickle.load(f)
    Pk_new_means.append(Pk_group0_linear)

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 3))
grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_new_means, Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["new\ mean", "\sigma=0.4,0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True, color_list=["Purple", "Crimson"])
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.95))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))

#plt.savefig("../figures/invented_sigma=0.4_0.2_ps_ratio_new_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_877364/1337713628.py:2: SyntaxWarning: invalid escape sequence '\ '
#   grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_new_means, Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["new\ mean", "\sigma=0.4,0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True, color_list=["Purple", "Crimson"])
# /tmp/ipykernel_877364/1337713628.py:2: SyntaxWarning: invalid escape sequence '\s'
#   grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_new_means, Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["new\ mean", "\sigma=0.4,0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True, color_list=["Purple", "Crimson"])
# is list
# ...

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group0_linear], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.4,0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
#plt.savefig("figures2/invented_sigma=0.4_0.2_ps_ratio_new_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  67.15194383778666
# shotnoise:  98.68026681304815
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4152673/117463783.py:1: SyntaxWarning: invalid escape sequence '\s'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group0_linear], mean_of_seeds_lists=[Pk_gaussian_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.4,0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_4152673/117463783.py:1: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25], len_k=30, ratio_ylabel_list=["TNG\ shuffled", " \sigma=0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.3))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.4,0.8))


#plt.savefig("figures2/tng_sigma0.2_ratio_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_4152673/778446466.py:2: SyntaxWarning: invalid escape sequence '\ '
#   grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25], len_k=30, ratio_ylabel_list=["TNG\ shuffled", " \sigma=0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
# /tmp/ipykernel_4152673/778446466.py:2: SyntaxWarning: invalid escape sequence '\s'
#   grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25], len_k=30, ratio_ylabel_list=["TNG\ shuffled", " \sigma=0.2"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
# ...

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([Pk_group0_interp], mean_of_seeds_lists=[Pk_shuffled_list], percentiles=[25], len_k=30, ratio_ylabel_list=["TNG\ shuffled", " \sigma=0"], mean_of_seeds_reverse=False, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.3))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.8))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.4,0.9))


#plt.savefig("figures2/tng_sigma0_ratio_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  303.7679168819041
# shotnoise:  178.73114770808178
# 0

# %%
fig, grey_leg = ps.compare_ps_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25,75], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=False, labels=[r"$\rm \sigma = 0$", r"$\rm \sigma = 0.4,0.2$", ""], ratio_ylabel_list = ["\sigma = 0", "\sigma=0.4,0.2"], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.6,0.625), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
#plt.savefig("figures2/invented_sigma=0.4_0.2_ps_ratio_new_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  66.63484058529829
# shotnoise:  98.68026681304815

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["\sigma = 0", " \sigma = 0.4,0.2"], mean_of_seeds_reverse=True, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.5))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))


#plt.savefig("figures2/invented_sigma=0.4_0.2_ps_ratio_orig_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  84.60423087309721
# shotnoise:  98.68026681304815

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([Pk_group0], mean_of_seeds_lists=[Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["\sigma = 0", " \sigma = 0.2"], mean_of_seeds_reverse=True, create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))

#plt.savefig("figures2/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  84.60423087309721
# shotnoise:  105.35907165955453

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["new\ mean", " \sigma = 0.4,0.2"], create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
#plt.savefig("figures2/invented_sigma=0.4_0.2_ps_ratio_new_mean.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  66.63484058529829
# shotnoise:  98.68026681304815
# 0
# 1

# %%
fig, ax = plt.subplots(figsize=(2*10/3, 4))
grey_leg = ps.residual_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], percentiles=[25], ratio_ylabel_list=["\mu_{new}", " \sigma = 0.4,0.2"], create_fig=False, ax=ax, plot_type="toy_model", return_grey_leg=True)
leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.65,0.75))
ax.add_artist(leg1)
ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
# Out:
# is list
# shotnoise:  66.63484058529829
# shotnoise:  98.68026681304815
# 0
# 1

# %%
import matplotlib.transforms as mtrans
from matplotlib.text import TextPath
from matplotlib.patches import PathPatch

fig = ps.compare_ps_plot([], mean_of_seeds_lists=[Pk_shuffled_list, Pk_gaussian_list], mean_of_seeds_reverse=False, len_k= 100, labels=["TNG Shuffled", r"$\rm \sigma = 0.2$", ""], ratio_ylabel_list = ["TNG shuffled", "\sigma=0.2"], dim=2, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.5), bbox_to_anchor_color=(0.6,0.625))#, ylim1=(0.9,1.4))
ax = fig.gca()
# plt.annotate(r"$\rm \sigma = $",fontsize=20,
#             xy=(0.59, 0.77), xycoords="figure fraction"
#             )
# #plt.annotate(r"$\{$",fontsize=50,
# ##            xy=(0.65, 0.755), xycoords='figure fraction'
#   #          )
# def curly(x,y, scale, ax=None):
#     if not ax: ax=plt.gca()
#     tp = TextPath((0, 0), "{", size=1)
#     trans = mtrans.Affine2D().scale(0.3, scale) + \
#         mtrans.Affine2D().translate(x,y) + ax.transData
#     pp = PathPatch(tp, lw=0, fc="k", transform=trans)
#     ax.add_artist(pp)
# curly(0.19,1.06,0.1, ax)

#plt.savefig("figures2/invented_sigma=0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# is list
# shotnoise:  130.38519438706456
# shotnoise:  105.35907165955453

# %%
import matplotlib.transforms as mtrans
from matplotlib.text import TextPath
from matplotlib.patches import PathPatch

fig = ps.compare_ps_plot([Pk_group10_invented], mean_of_seeds_lists=[Pk_shuffled_list], mean_of_seeds_reverse=False, len_k= 100, labels=["TNG Shuffled", r"$\rm \sigma = 0$", ""], ratio_ylabel_list = ["TNG shuffled", "\sigma=0"], dim=2, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.5), bbox_to_anchor_color=(0.6,0.625))#, ylim1=(0.9,1.4))
ax = fig.gca()
# plt.annotate(r"$\rm \sigma = $",fontsize=20,
#             xy=(0.59, 0.77), xycoords="figure fraction"
#             )
# #plt.annotate(r"$\{$",fontsize=50,
# ##            xy=(0.65, 0.755), xycoords='figure fraction'
#   #          )
# def curly(x,y, scale, ax=None):
#     if not ax: ax=plt.gca()
#     tp = TextPath((0, 0), "{", size=1)
#     trans = mtrans.Affine2D().scale(0.3, scale) + \
#         mtrans.Affine2D().translate(x,y) + ax.transData
#     pp = PathPatch(tp, lw=0, fc="k", transform=trans)
#     ax.add_artist(pp)
# curly(0.19,1.06,0.1, ax)

#plt.savefig("figures2/invented_sigma=0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# is list
# shotnoise:  303.7679168819041
# shotnoise:  178.3851769132499
# 0.04097135711096481 0.0397108977526622
# 0.040457994868822345 0.039717800618123425
# [0.65658694 0.66135701 0.66606123 0.67072642 0.67534206 0.67989325
#  0.68440653 0.68887439 0.69329847 0.69767933] [1.0015964851958867, 1.0122881107147905, 0.9947724851781291, 0.9835826694745984, 1.005410144360839, 0.9689489204126184, 0.9506459631240073, 0.9664056265437277, 0.9578790827708621, 0.924155395162554]
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1442: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
import matplotlib.transforms as mtrans
from matplotlib.text import TextPath
from matplotlib.patches import PathPatch

fig = ps.compare_ps_plot([], marker_size=5, mean_of_seeds_lists=[Pk_gaussian_list_mean, Pk_gaussian_list], labels=["TNG Shuffled", r"$\rm \quad\quad\ 0.4\ for\ M_h < 10^{12}$"+ "\n" +r"$\rm\quad\quad\ 0.2\ for\ M_h > 10^{12}$"], ratio_ylabel_list = ["\sigma=0", "\sigma=0.4,0.2"], dim=2, mean_of_seeds_reverse=False, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.5), bbox_to_anchor_color=(0.39,0.6))#, ylim1=(0.9,1.4))
ax = fig.gca()
plt.annotate(r"$\rm \sigma = $",fontsize=20,
            xy=(0.59, 0.76), xycoords="figure fraction"
            )
#plt.annotate(r"$\{$",fontsize=50,
##            xy=(0.65, 0.755), xycoords='figure fraction'
  #          )
def curly(x,y, scale, ax=None):
    if not ax: ax=plt.gca()
    tp = TextPath((0, 0), "{", size=1)
    trans = mtrans.Affine2D().scale(0.2, scale) + \
        mtrans.Affine2D().translate(x,y) + ax.transData
    pp = PathPatch(tp, lw=0, fc="k", transform=trans)
    ax.add_artist(pp)
curly(0.19,1.35,0.12, ax)

#plt.savefig("figures2/invented_sigma=0.4_0.2_ps_ratio_new_mean.pdf", format="pdf", bbox_inches="tight")
plt.show()
plt.close()
# Out:
# is list
# shotnoise:  66.63484058529829
# shotnoise:  212.22482152183875
# 0.03634227573277014 0.03606578008021117
# 0.03954628296080506 0.03866567395806005
# [1.22362468 1.22492175 1.22621479 1.22750248 1.22878562 1.23006629
#  1.23134281 1.23261514 1.23388477 1.23515074] [5.0441197259005036e-05, 0.0009400820855385126, 0.0017067085103952364, 0.0025216475646703167, 0.0016117410824490741, 0.0028406346943876787, 0.001972673889869558, 0.0006177804799290432, 0.00026373351890296865, 0.0004056191109540532]
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1442: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
