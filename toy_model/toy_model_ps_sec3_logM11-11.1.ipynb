# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group1 = pickle.load(f)

# %%
random_list = []
for iseed in range(3):
    fname = f"{odir}/weight1_5_random_seed{iseed}.pickle"
    with open(fname, "rb") as f:
        Pk_mean_group10 = pickle.load(f)
        Pk_group12 = pickle.load(f)
        random_list.append(Pk_group12)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1_5_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight5_1_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_reverse = pickle.load(f)

# %%
odir = "/cosma/home/dp004/dc-zhan5/paper1/ps_data/snap40/mvir/toy_model/logM11-11.1"
fname = f"{odir}/weight1(25)_5(75)_cprox.pickle"
with open(fname, "rb") as f:
    Pk_mean_group10 = pickle.load(f)
    Pk_group12_cprox_per = pickle.load(f)

# %%
fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (c<c_{50}), W=5\ (c>c_{50}) $", "$W=1\ (c>c_{50}), W=5\ (c<c_{50})$",  "$W=1\ (c_{\mathrm{rand}}), W=5\ (c_{\mathrm{rand}})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()
ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.65))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.85))
ax.add_artist(leg1)

leg0 = ax.legend(handles=[color_leg[1]], loc="upper left", bbox_to_anchor=(0.05,1), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg0)
leg1 = ax.legend(handles=[color_leg[3]], loc="upper left", bbox_to_anchor=(0.45,0.65), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
leg1 = ax.legend(handles=[color_leg[2]], loc="upper left", bbox_to_anchor=(0.38,0.4), fontsize=16, handlelength=1, handletextpad=0.5)
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.85,1.6)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  193.40273880345717
# shotnoise:  279.3620845014718
# shotnoise:  279.3620845014718
# shotnoise:  279.3569387373952
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_877184/1346418704.py:1: SyntaxWarning: invalid escape sequence '\ '
#   fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (c<c_{50}), W=5\ (c>c_{50}) $", "$W=1\ (c>c_{50}), W=5\ (c<c_{50})$",  "$W=1\ (c_{\mathrm{rand}}), W=5\ (c_{\mathrm{rand}})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877184/1346418704.py:1: SyntaxWarning: invalid escape sequence '\ '
#   fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (c<c_{50}), W=5\ (c>c_{50}) $", "$W=1\ (c>c_{50}), W=5\ (c<c_{50})$",  "$W=1\ (c_{\mathrm{rand}}), W=5\ (c_{\mathrm{rand}})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877184/1346418704.py:1: SyntaxWarning: invalid escape sequence '\ '
#   fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (c<c_{50}), W=5\ (c>c_{50}) $", "$W=1\ (c>c_{50}), W=5\ (c<c_{50})$",  "$W=1\ (c_{\mathrm{rand}}), W=5\ (c_{\mathrm{rand}})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877184/1346418704.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, color_leg, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, return_solid_leg=True, mean_of_seeds_reverse=True, labels=[r"random","$W=1\ (c<c_{50}), W=5\ (c>c_{50}) $", "$W=1\ (c>c_{50}), W=5\ (c<c_{50})$",  "$W=1\ (c_{\mathrm{rand}}), W=5\ (c_{\mathrm{rand}})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=False, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_877184/1346418704.py:3: SyntaxWarning: invalid escape sequence '\s'
#   ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1503: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.85, 1.6)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "$W=5 (c>c_{50}), W=1 (c<c_{50})$", "$W=1 (c<c_{50})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()
ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.65))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,1))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.85,1.6)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  193.40273880345717
# shotnoise:  279.3620845014718
# shotnoise:  279.3620845014718
# shotnoise:  279.3569387373952
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_2837373/2017686943.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, Pk_group12_cprox, Pk_group12_cprox_reverse], mean_of_seeds_lists=[random_list],grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "$W=5 (c>c_{50}), W=1 (c<c_{50})$", "$W=1 (c<c_{50})$","",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.4,0.7), toy_model=True)#, ylim1=(0.9,1.4))
# /tmp/ipykernel_2837373/2017686943.py:3: SyntaxWarning: invalid escape sequence '\s'
#   ax.annotate(f"logM $\sim$ 11", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")
# (0.85, 1.6)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, random_list[0], Pk_group12_cprox, Pk_group12_cprox_reverse], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.5)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  193.40273880345717
# shotnoise:  279.3569387373952
# shotnoise:  279.3620845014718
# shotnoise:  279.3620845014718
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2822808/841968747.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, random_list[0], Pk_group12_cprox, Pk_group12_cprox_reverse], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# (0.8, 1.5)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, *random_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  193.40273880345717
# shotnoise:  279.3569387373952
# shotnoise:  279.3569387373952
# shotnoise:  279.3569387373952
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2822808/279658172.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, *random_list], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=True,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# (0.8, 1.8)

# %%
fig, grey_leg = ps.compare_ps_plot([Pk_group1, random_list[0], Pk_group12_cprox, Pk_group12_cprox_reverse, Pk_group12_cprox_per], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
ax = plt.gca()

leg0 = ax.legend(handles=[grey_leg[0]], loc="upper left", bbox_to_anchor=(0.05,0.6))
ax.add_artist(leg0)
leg1 = ax.legend(handles=[grey_leg[1]], loc="upper left", bbox_to_anchor=(0.05,0.9))
ax.add_artist(leg1)
#ax.legend(handles=[grey_leg[2]], loc="upper left", bbox_to_anchor=(0.65,0.35))
plt.ylim(0.8,1.8)
#plt.savefig("../figures/invented_sigma0.2_ps_ratio.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  193.40273880345717
# shotnoise:  279.3569387373952
# shotnoise:  279.3620845014718
# shotnoise:  279.3620845014718
# shotnoise:  338.45587832238414
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_2822808/4120051039.py:1: SyntaxWarning: invalid escape sequence '\m'
#   fig, grey_leg = ps.compare_ps_plot([Pk_group1, random_list[0], Pk_group12_cprox, Pk_group12_cprox_reverse, Pk_group12_cprox_per], grey_legend=False, return_grey_leg=True, mean_of_seeds_reverse=True, labels=[r"random", r"random", "High b = High W", "High b = Low W",""], ratio_ylabel_list = ["\mathrm{no\ scatter}", ""], dim=3, residuals_only=True, color_legend=True, shotnoise_subtracted_ps=False,  shotnoise_ps = True, bbox_to_anchor_grey=(0,0.8), bbox_to_anchor_color=(0.5,0.6), toy_model=True)#, ylim1=(0.9,1.4))
# (0.8, 1.8)
