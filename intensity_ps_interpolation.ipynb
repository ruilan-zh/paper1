# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
    
    
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir="/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_ncore28/snap40/interp_schemes"

# %%
odir="/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_subhaloflag_beforeNov/snap40/interp_schemes"

# %%
ps-intensity-mvir_logM10.pickle

# %%
odir1 = "/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_subhaloflag_beforeNov/snap40/subhaloflag_all"
with open(f"{odir1}/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal_tsc = pickle.load(f)
    Pk_gal_tsc = pickle.load(f)

# %%
with open(f"{odir}/ps-intensity-gal_logM10_nearest.pickle", "rb") as f:
    Pk_mean_gal_ngp = pickle.load(f)
    Pk_gal_ngp = pickle.load(f)

# %%
with open(f"{odir}/ps-intensity-gal_logM10_cic.pickle", "rb") as f:
    Pk_mean_gal_cic = pickle.load(f)
    Pk_gal_cic = pickle.load(f)

# %%
with open(f"{odir}/ps-intensity-gal_logM10_tsc_Nmesh4495_interlacing_448.pickle", "rb") as f:
    Pk_mean_gal2 = pickle.load(f)
    Pk_gal2 = pickle.load(f)

# %%
with open(f"{odir}/ps-intensity-gal_logM10_tsc_Nmesh4494.pickle", "rb") as f:
    Pk_mean_gal2 = pickle.load(f)
    Pk_gal2 = pickle.load(f)

# %%
knyq = np.pi * 2247 / 205

# %%
np.where(Pk_gal_tsc["k"]>knyq)
# Out:
# (array([688]),)

# %%
ik = 688

# %%
shot = Pk_gal2.attrs["shotnoise"]

# %%
print(Pk_gal2.attrs["shotnoise"])
# Out:
# 134.51343275181105

# %%
ref = Pk_gal2["power"].real[ik]-shot
tsc = Pk_gal_tsc["power"].real[ik]-shot
cic = Pk_gal_cic["power"].real[ik]-shot
ngp = Pk_gal_ngp["power"].real[ik]-shot

# %%
Pk_gal_ngp["power"].real[ik]
# Out:
# 81.5861609453376

# %%
print(tsc/ref)
print(cic/ref)
print(ngp/ref)
# Out:
# 0.9940801034100187
# 1.2238676532788766
# -5.670658678912263

# %%
ik = int(ik/2)

# %%
ref = Pk_gal2["power"].real[ik]
tsc = Pk_gal_tsc["power"].real[ik]
cic = Pk_gal_cic["power"].real[ik]
ngp = Pk_gal_ngp["power"].real[ik]

# %%
print(100*(1-tsc/ref))
print(cic/ref)
print(ngp/ref)
# Out:
# 0.0030841508366186154
# 1.0017175529659115
# 0.8538355857331061

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], labels=["Nmeshx2", "TSC", "CIC", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=690, bbox_to_anchor_color=(0,0.45))
plt.xlim(-1.55,1.6)
plt.ylim(0.99, 1.01)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
# Out:
# shotnoise:  134.51343275181105
# 689
# 690
# shotnoise:  134.51343275181105
# 689
# 690
# shotnoise:  134.51343275181105
# 689
# 690
# shotnoise:  134.51343275181105
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], labels=["Nmeshx2", "TSC", "CIC", "NGP"], total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.45), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"])
plt.xlim(-1.55,1.6)
#plt.ylim(0.99, 1.01)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "TSC", "CIC", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.45), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=False)
plt.xlim(-1.55,1.6)
#plt.ylim(0.98, 1.2)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
#plt.savefig("figures/interp_scheme.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "TSC", "CIC", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.45), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=False)
plt.xlim(-1.55,1.6)
plt.ylim(0.985, 1.015)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
#plt.savefig("figures/interp_scheme.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "TSC", "CIC", "NGP"], total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.45), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=True)
plt.xlim(-1.55,1.6)
plt.ylim(0.95, 1.01)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
odir2="/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_subhaloflag_beforeNov/snap40/interp_schemes/no_interlacing"

# %%
with open(f"{odir2}/ps-intensity-gal_logM10_nearest.pickle", "rb") as f:
    Pk_mean_gal_ngp = pickle.load(f)
    Pk_gal_ngp = pickle.load(f)

# %%
with open(f"{odir2}/ps-intensity-gal_logM10_cic.pickle", "rb") as f:
    Pk_mean_gal_cic = pickle.load(f)
    Pk_gal_cic = pickle.load(f)

# %%
with open(f"{odir2}/ps-intensity-gal_logM10_tsc_Nmesh4495_interlacing_448.pickle", "rb") as f:
    Pk_mean_gal2 = pickle.load(f)
    Pk_gal2 = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-4ea32cef5cdc> in <module>()
#       1
# ----> 2 with open(f"{odir2}/ps-intensity-gal_logM10_tsc_Nmesh4495_interlacing_448.pickle", "rb") as f:
#       3     Pk_mean_gal2 = pickle.load(f)
#       4     Pk_gal2 = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_subhaloflag_beforeNov/snap40/interp_schemes/no_interlacing/ps-intensity-gal_logM10_tsc_Nmesh4495_interlacing_448.pickle'

# %%
with open(f"{odir2}/ps-intensity-gal_logM10_tsc_Nmesh4494.pickle", "rb") as f:
    Pk_mean_gal2 = pickle.load(f)
    Pk_gal2 = pickle.load(f)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_cic, Pk_gal_ngp], shotnoise_subtracted_ps=True, residuals_only=True, len_k=600)
plt.xlim(-1.55,1.55)
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# (-1.55, 1.55)

# %%
odir1 = "/cosma/home/dp004/dc-zhan5/nbodykit-ps/ps_data_old/ps_data_subhaloflag_beforeNov/snap40/interp_schemes"
with open(f"{odir2}/ps-intensity-gal_logM10_tsc.pickle", "rb") as f:
    Pk_mean_gal_tsc = pickle.load(f)
    Pk_gal_tsc2 = pickle.load(f)

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_tsc2], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "Interlacing", "No interlacing", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.6), bbox_to_anchor_grey=(0,1), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=False)
plt.xlim(-1.55,1.6)
plt.ylim(0.99, 1.08)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)

#plt.savefig("figures/interlacing.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_tsc2], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "Interlacing", "No interlacing", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.6), bbox_to_anchor_grey=(0,1), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=False)
plt.xlim(-1.55,1.6)
plt.ylim(0.99, 1.08)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)
ax = plt.gca()


# inset axes....
x1, x2, y1, y2 = 10, 10.6, 1, 1.01  # subregion of the original image
axins = ax.inset_axes(
    [0.1, 0.4, 0.6, 0.6],
    xlim=(x1, x2), ylim=(y1, y2))
axins.plot(arr_all,(Pk_gal_tsc-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))

ax.indicate_inset_zoom(axins, edgecolor="black")
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-4c6b39aa0268> in <module>()
#      12     [0.1, 0.4, 0.6, 0.6],
#      13     xlim=(x1, x2), ylim=(y1, y2))
# ---> 14 axins.plot(arr_all,(Pks-shot_arr)/(Pk_gal_all["power"].real[ik]-Pk_gal_all.attrs["shotnoise"]))
#      15
#      16 ax.indicate_inset_zoom(axins, edgecolor="black")
#
# NameError: name 'arr_all' is not defined

# %%
ik = 688

# %%
ref = Pk_gal2["power"].real[ik]
tsc = Pk_gal_tsc["power"].real[int(ik/2)]-shot
cic = Pk_gal_cic["power"].real[ik]
ngp = Pk_gal_ngp["power"].real[ik]
inter = Pk_gal_tsc2["power"].real[ik]

# %%
print(1-tsc/ref)
print(inter/ref)
# Out:
# -0.09905479420442842
# 1.0057786771577881

# %%
ref = Pk_gal2["power"].real[int(ik/2)]-shot
inter = Pk_gal_tsc2["power"].real[int(ik/2)]-shot

# %%
print(1-tsc/ref)
print(inter/ref)
# Out:
# 0.00020672537235377764
# 1.0023486182769852

# %%
ps.compare_ps_plot([Pk_gal2, Pk_gal_tsc, Pk_gal_tsc2], ratio_ylabel_list=[r"Nmesh \times 2",""], labels=["Nmeshx2", "Interlacing", "No interlacing", "NGP"], total_ps=True, shotnoise_ps=False, shotnoise_subtracted_ps=True, residuals_only=True, len_k=670, bbox_to_anchor_color=(0,0.45), dots4group=True, color_list=["k"]+palette_tab10[3:4]+["DodgerBlue","Purple"], toy_model=False)
plt.xlim(-1.55,1.6)
plt.ylim(0.99, 1.01)
plt.vlines(np.log10(knyq), 0.5, 1.1, linestyle="dashed", color="k", linewidth=1.5)
plt.vlines(np.log10(knyq/2), 0.5, 1.1, linestyle="dotted", color="k", linewidth=1.5)

#plt.savefig("../figures/interp_scheme.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
# shotnoise:  134.51343275181105
