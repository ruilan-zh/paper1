# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_sum10 = pickle.load(f)
print("shotnoise", Pk_sum10.attrs["shotnoise"])
# Out:
# shotnoise 304.0903879154701

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/Nmesh562/ps-intensity-group_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_Nmesh562_sum = pickle.load(f)
print("shotnoise", Pk_Nmesh562.attrs["shotnoise"])
# Out:
# shotnoise 304.0903879154707

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/Nmesh562/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_Nmesh562_gal = pickle.load(f)
print("shotnoise", Pk_Nmesh562_gal.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
ps.compare_ps_plot([Pk_gal10, Pk_Nmesh562_gal], residuals_only=False, shotnoise_subtracted_ps=True)
# Out:
# shotnoise:  130.52360745197086
# 172
# 344
# shotnoise:  130.52360745197086

# %%
ps.compare_ps_plot([Pk_gal10, Pk_Nmesh562_gal], residuals_only=True, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False,)
# Out:
# shotnoise:  130.52360745197086
# 172
# 344
# shotnoise:  130.52360745197086

# %%
ps.compare_ps_plot([Pk_sum10, Pk_Nmesh562], residuals_only=False, shotnoise_subtracted_ps=True)
# Out:
# shotnoise:  304.0903879154701
# 172
# 344
# shotnoise:  304.0903879154707
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1487: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_sum10, Pk_Nmesh562], residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False)
# Out:
# shotnoise:  304.0903879154701
# 172
# 344
# shotnoise:  304.0903879154707
