# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_sum10 = pickle.load(f)
print("shotnoise", Pk_sum10.attrs["shotnoise"])
# Out:
# shotnoise 304.0903879154701

# %%
odir = "../ps_data/snap25"
with open(f"{odir}/mvir/ps-intensity-group_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_sum10_25 = pickle.load(f)
print("shotnoise", Pk_sum10.attrs["shotnoise"])
# Out:
# shotnoise 304.0903879154701

# %%
odir = "../ps_data/snap25"
with open(f"{odir}/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10_25 = pickle.load(f)
print("shotnoise", Pk_sum10.attrs["shotnoise"])
# Out:
# shotnoise 304.0903879154701

# %%
ps.compare_ps_plot([Pk_sum10, Pk_sum10_25], residuals_only=False, shotnoise_subtracted_ps=True)
# Out:
# shotnoise:  304.0903879154701
# shotnoise:  493.1632201614001
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1487: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal10_25], residuals_only=False, shotnoise_subtracted_ps=True)
# Out:
# shotnoise:  290.6573669268956

# %%
ps.compare_ps_plot([Pk_sum10_25], residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False)
# Out:
# shotnoise:  493.1632201614001

# %%
ps.compare_ps_plot([Pk_gal10_25, Pk_sum10_25], var=True, residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=True)
#plt.ylim(0,100)
# Out:
# shotnoise:  290.6573669268956
# shotnoise:  493.1632201614001
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1487: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_sum10_25], var=True, residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False)
#plt.ylim(0,100)
# Out:
# shotnoise:  493.1632201614001

# %%
ps.compare_ps_plot([Pk_gal10_25], var=True, residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False)
# Out:
# shotnoise:  290.6573669268956

# %%
ps.compare_ps_plot([Pk_gal10_25, Pk_sum10_25], var=False, residuals_only=False, total_ps=False, shotnoise_ps=False, shotnoise_subtracted_ps=True, log=False)
#plt.ylim(0,100)
# Out:
# shotnoise:  290.6573669268956
# shotnoise:  493.1632201614001
