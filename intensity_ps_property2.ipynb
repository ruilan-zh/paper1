# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)
print("shotnoise", Pk_cent10.attrs["shotnoise"])
# Out:
# shotnoise 201.65155090472237

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sat_logM10.pickle", "rb") as f:
    Pk_mean_sat10 = pickle.load(f)
    Pk_sat10 = pickle.load(f)
print("shotnoise", Pk_sat10.attrs["shotnoise"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-405acae62307> in <module>()
#       1
#       2 odir = "ps_data"
# ----> 3 with open(f"{odir}/snap40/mvir/ps-intensity-sat_logM10.pickle", "rb") as f:
#       4     Pk_mean_sat10 = pickle.load(f)
#       5     Pk_sat10 = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ps_data/snap40/mvir/ps-intensity-sat_logM10.pickle'

# %%
logM_name = "logM11-13.8"
logM_ps_name = ""
ps_type = "sat"
object2shuffle = "sat"
#property_name = "conc_proxy"
property_name = "msat_sum"
#property_name = "dMdyn"
#property_name = "test"
Nsplits = [2, 4]
#split_name = f"split_nan/{property_name}_split{Nsplit}"
Nsplit=4
#split_names = [f"split_nan/{property_name}_split{Nsplit}/{property_name2}_split{Nsplit}"]
split_names = [f"split_nan/{property_name}_split{Nsplit}" for Nsplit in Nsplits]
Nsplit = 4
property_names = ["dMdyn","msat_sum"]
#split_names = [f"{property_name}_split{Nsplit}" for property_name in property_names]
object2shuffle_list = [object2shuffle]*2

# %%
logM_name = "shuffle_all/logM11-13.8"
logM_ps_name = ""
ps_type = "gal"
object2shuffle = "gal"
property_name = "conc_proxy"
property_name = "msat_sum"
#property_name = "test"
Nsplits = [4]
split_name = f"{property_name}_split{Nsplit}"
split_names = [f"{property_name}_split{Nsplit}" for Nsplit in Nsplits]

object2shuffle_list = [object2shuffle]*2

# %%
logM_name = "logM11.5-12"
object2shuffle_list = ["gal", "cent_sat"]
property_name = "conc_proxy"
property_name2 = "msat_sum"
Nsplit = 2
split_name1 = f"split_nan/{property_name}_split{Nsplit}/{property_name2}_split{Nsplit}"
split_name2 = f"{property_name}_split{Nsplit}_{property_name2}_split{Nsplit}"
split_names = [split_name1, split_name2]

# %%
logM_name = "logM11-13.8/logM11-11.5,logM12-13.8,logM11.5-12"
object2shuffle_list = ["gal,cent_sat"]*2
property_name = "conc_proxy"
property_name2 = "msat_sum"
Nsplit = 4

split_name1 = f"/conc_proxy_split2,msat_sum_split4,conc_proxy_split4_msat_sum_split4"
split_names = [split_name1]*2

# %%
object2shuffle_list =["gal"]
logM_name = "logM11-13.8"
property_name = "msat_sum"
Nsplit=4
split_name2 = f"split_nan/{property_name}_split{Nsplit}"
split_names = [split_name2]*2

# %%
logM_name = ""
split_name = ""
interp="tsc"
Pk_shuffled_list = []
names_list = []
seed_i = 0
seed_f = 100
n_seed = seed_f - seed_i
        
power_list = []
mean_intensities = []
odir = "ps_data"
snapnum=40

for seed in range(seed_i,seed_f): 
    fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/{ps_type}_ps/shuffle_{object2shuffle}/{logM_name}/{logM_ps_name}/seed{seed}.pickle"
    if seed == 0:
        print(fname)
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
        Pk_shuffled_list.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")
        

power_arr = np.array(power_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_gal///seed0.pickle
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197075
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197086
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197075
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083

# %%
interp="tsc"
object2shuffle = object2shuffle_list[0]
split_name = split_names[0]
Pk_shuffled_list1 = []
names_list = []
seed_i = 0
seed_f = 100
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
odir = "ps_data"
snapnum=40

for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/{ps_type}_ps/shuffle_{object2shuffle}/{logM_name}/{split_name}/seed{seed}.pickle"
    if seed == 0:
        print(fname)
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
        Pk_shuffled_list1.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")
        

power_arr = np.array(power_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_gal/shuffle_all/logM11-13.8/msat_sum_split4/seed0.pickle
# shotnoise 130.52360745197097
# shotnoise 130.52360745197078
# shotnoise 130.52360745197078
# shotnoise 130.5236074519709
# shotnoise 130.52360745197078
# shotnoise 130.52360745197075
# shotnoise 130.52360745197078
# shotnoise 130.52360745197075
# shotnoise 130.52360745197078
# shotnoise 130.52360745197075
# shotnoise 130.52360745197058
# shotnoise 130.52360745197086
# shotnoise 130.52360745197097
# shotnoise 130.5236074519708
# shotnoise 130.52360745197086
# shotnoise 130.52360745197095
# shotnoise 130.52360745197078
# shotnoise 130.5236074519706
# shotnoise 130.52360745197103
# shotnoise 130.52360745197095
# shotnoise 130.52360745197075
# shotnoise 130.52360745197072
# shotnoise 130.52360745197086
# shotnoise 130.52360745197095
# shotnoise 130.52360745197055
# shotnoise 130.5236074519708
# shotnoise 130.5236074519711
# shotnoise 130.52360745197092
# shotnoise 130.52360745197097
# shotnoise 130.52360745197075
# shotnoise 130.5236074519708
# shotnoise 130.52360745197075
# shotnoise 130.52360745197046
# shotnoise 130.52360745197083
# shotnoise 130.5236074519707
# shotnoise 130.5236074519709
# shotnoise 130.5236074519708
# shotnoise 130.5236074519707
# shotnoise 130.52360745197078
# shotnoise 130.52360745197072
# shotnoise 130.52360745197083
# shotnoise 130.52360745197066
# shotnoise 130.5236074519708
# shotnoise 130.5236074519708
# shotnoise 130.52360745197103
# shotnoise 130.52360745197063
# shotnoise 130.52360745197066
# shotnoise 130.52360745197083
# shotnoise 130.5236074519707
# shotnoise 130.5236074519709
# shotnoise 130.52360745197097
# shotnoise 130.52360745197095
# shotnoise 130.5236074519708
# shotnoise 130.52360745197106
# shotnoise 130.52360745197103
# shotnoise 130.52360745197095
# shotnoise 130.5236074519708
# shotnoise 130.5236074519709
# shotnoise 130.5236074519708
# shotnoise 130.52360745197097
# shotnoise 130.52360745197063
# shotnoise 130.52360745197075
# shotnoise 130.5236074519709
# shotnoise 130.5236074519709
# shotnoise 130.52360745197078
# shotnoise 130.5236074519707
# shotnoise 130.52360745197058
# shotnoise 130.52360745197083
# shotnoise 130.52360745197103
# shotnoise 130.5236074519709
# shotnoise 130.52360745197078
# shotnoise 130.52360745197075
# shotnoise 130.52360745197083
# shotnoise 130.52360745197078
# shotnoise 130.52360745197066
# shotnoise 130.5236074519709
# shotnoise 130.52360745197066
# shotnoise 130.5236074519705
# shotnoise 130.52360745197072
# shotnoise 130.52360745197078
# shotnoise 130.52360745197083
# shotnoise 130.52360745197078
# shotnoise 130.52360745197078
# shotnoise 130.52360745197072
# shotnoise 130.52360745197078
# shotnoise 130.52360745197066
# shotnoise 130.52360745197072
# shotnoise 130.5236074519708
# shotnoise 130.5236074519708
# shotnoise 130.5236074519709
# shotnoise 130.52360745197086
# shotnoise 130.52360745197086
# shotnoise 130.52360745197066
# shotnoise 130.52360745197086
# shotnoise 130.5236074519709
# shotnoise 130.52360745197078
# shotnoise 130.5236074519707
# shotnoise 130.5236074519708
# shotnoise 130.52360745197083
# shotnoise 130.52360745197078

# %%
interp="tsc"

object2shuffle = object2shuffle_list[1]
split_name = split_names[1]
Pk_shuffled_list2 = []
names_list = []
seed_i = 0
seed_f = 100
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
odir = "ps_data"
snapnum=40
#logM_name = "logM11-13.8"
#split_name = "split_nan/dMdyn_split4"
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/{ps_type}_ps/shuffle_{object2shuffle}/{logM_name}/{split_name}/seed{seed}.pickle"
    #fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogMdefault.1/{ps_type}_ps/shuffle_{object2shuffle}/shuffle_all/{logM_name}/{split_name}/seed{seed}.pickle"
    
    if seed == 0:
        print(fname)
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
        Pk_shuffled_list2.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")
        

power_arr = np.array(power_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_gal,cent_sat/logM11-13.8/logM11-11.5,logM12-13.8,logM11.5-12//conc_proxy_split2,msat_sum_split4,conc_proxy_split4_msat_sum_split4/seed0.pickle
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197052
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197063
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.5236074519705
# shotnoise 130.52360745197055
# shotnoise 130.52360745197066
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197066
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197063
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055

# %%
interp="tsc"

object2shuffle = object2shuffle_list[1]
split_name = split_names[1]
Pk_shuffled_list3 = []
names_list = []
seed_i = 0
seed_f = 100
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
odir = "ps_data"
snapnum=40

for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/{ps_type}_ps/shuffle_{object2shuffle}/{logM_name}/{split_name}/seed{seed}.pickle"
    #fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogMdefault.1/{ps_type}_ps/shuffle_{object2shuffle}/shuffle_all/{logM_name}/{split_name}/seed{seed}.pickle"
    
    if seed == 0:
        print(fname)
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
        Pk_shuffled_list3.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")
        

power_arr = np.array(power_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_gal,cent_sat/logM11-13.8/logM11-11.5,logM12-13.8,logM11.5-12//conc_proxy_split2,msat_sum_split4,conc_proxy_split4_msat_sum_split4/seed0.pickle
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197052
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197063
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.5236074519705
# shotnoise 130.52360745197055
# shotnoise 130.52360745197066
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197046
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.5236074519705
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197066
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197063
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.52360745197055
# shotnoise 130.5236074519707
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197046
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197058
# shotnoise 130.52360745197055

# %%
interp="tsc"

object2shuffle = object2shuffle_list[1]
split_name = split_names[1]
Pk_shuffled_list3 = []
names_list = []
seed_i = 0
seed_f = 100
n_seed = seed_f - seed_i

power_list = []
mean_intensities = []
odir = "ps_data"
snapnum=40
logM_name = "logM13.6-13.8"
split_name = "msat_sum_split8"
for seed in range(seed_i,seed_f):
    fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/{ps_type}_ps/shuffle_{object2shuffle}/{logM_name}/{split_name}/seed{seed}.pickle"
    if seed == 0:
        print(fname)
    with open(fname, "rb") as f:
        Pk_mean_gal_shuffled = pickle.load(f)
        #print("mean", Pk_mean_cent_shuffled)
        Pk_gal_shuffled = pickle.load(f)
        #print(Pk_mean_gal_shuffled)
        power_list.append(Pk_gal_shuffled["power"].real)
        
        mean_intensities.append(Pk_mean_gal_shuffled)
        
        print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
        Pk_shuffled_list3.append(Pk_gal_shuffled)
        names_list.append(f"seed{seed}")
        

power_arr = np.array(power_list)
# Out:
# ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_gal/logM13.6-13.8/msat_sum_split8/seed0.pickle
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063
# shotnoise 130.52360745197063

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1], labels=["No split", "Msat_sum (4)", "Msat_sum (8)"],percentiles=[25,5], ratio_ylabel_list = ["Shuffled", ""], tng_shuffle_type="property", return_color_leg=True)
ax = plt.gca()

#ax.annotate(f"{logM_name}", (0.95,0.4), xycoords="axes fraction", ha="right", weight="bold")
ax.annotate(f"logM < 11", (0.95,0.4), xycoords="axes fraction", ha="right", weight="bold")

#plt.savefig("figures/logM13.6-13.8_dlogM0.2.pdf", format="pdf", bbox_inches="tight")
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0, 0.6))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[fr"{Nsplits[0]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.85
                                                                                            ))
ax.add_artist(leg)
#leg = ax.legend(handles=color_leg[2:], labels=[fr"8 percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.73))
#ax.add_artist(leg)
ax.annotate(r"Split by $\rm \widetilde{V}_{max}$", (0.9,0.85), xycoords="axes fraction", ha="right")

#ax.annotate(r"Split by $\rm dM/dt_{dyn}$", (0.9,0.85), xycoords="axes fraction", ha="right")
#plt.ylim(0.95,1.07)
#plt.savefig("figures/logMmax11_vmax_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197055
# shotnoise:  130.52360745197058
# shotnoise:  130.5236074519707
# 0
# 1

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], labels=["No split", "Msat_sum (4)", "Msat_sum (8)"],percentiles=[25,5], ratio_ylabel_list = ["Shuffled", ""], tng_shuffle_type="property", ps_type="cent",return_color_leg=True)
ax = plt.gca()
ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

#plt.savefig("figures/logM13.6-13.8_dlogM0.2.pdf", format="pdf", bbox_inches="tight")
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[fr"{Nsplits[0]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[fr"4 percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.73))
ax.add_artist(leg)
ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")
#plt.ylim(0.985,1.021)
#plt.savefig("figures/msat_all_sat_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# 1
# 2
# Text(0.9, 0.85, 'Split by $\\rm M_{sat}$')

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[fr"{Nsplits[0]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[fr"{Nsplits[1]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.73))
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.92,1.14)
plt.legend()
#plt.savefig("figures/logMall_msat_split_4_100.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.5236074519708
# shotnoise:  130.52360745197092
# shotnoise:  130.52360745197092
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
import matplotlib.ticker as ticker

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], labels=["No split", "Msat_sum (4)", "Msat_sum (8)"],percentiles=[25,5], ratio_ylabel_list = ["Random", ""], tng_shuffle_type="property", return_color_leg=True)
ax = plt.gca()
#ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

#plt.savefig("figures/logM13.6-13.8_dlogM0.2.pdf", format="pdf", bbox_inches="tight")
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$\rm M_{{sat}} ({Nsplit})$"], loc='upper left', bbox_to_anchor=(0.55, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"$\rm Random ({Nsplit})$"], loc='upper left', bbox_to_anchor=(0.55, 0.73))
ax.add_artist(leg)
ax.annotate(r"Split by", (0.85,0.85), xycoords="axes fraction", ha="right")

#ax.annotate(r"Split by $\rm dM/dt_{dyn}$", (0.9,0.85), xycoords="axes fraction", ha="right")
#plt.ylim(0.93,1.15)
plt.ylim(0.92,1.14)

#plt.savefig("figures/logMall_test_vs_msat4.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# shotnoise:  130.52360745197083
# shotnoise:  130.52360745197078
# shotnoise:  130.5236074519708
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[fr"M$_{{\mathrm{{sat}}}}$ ({Nsplits[0]})"], loc='upper left', bbox_to_anchor=(0.6, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[fr"various"], loc='upper left', bbox_to_anchor=(0.6, 0.73))
#ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
ax.annotate(r"Split by", (0.9,0.85), xycoords="axes fraction", ha="right")

#ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.92,1.14)
plt.legend()
#plt.savefig("figures/logMall_msat4.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197083
# shotnoise:  130.52360745197078
# shotnoise:  130.5236074519707
# 0
# 1

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[rf"{Nsplits[0]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.85))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"{Nsplits[1]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.73))
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
ax.annotate(r"Split by $\rm \widetilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
#ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.95,1.065)
plt.legend()
#plt.savefig("figures/logM12-12.5_conc_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
logM_name = "logM12.5-13"
logM_ps_name = ""
ps_type = "gal"
object2shuffle = "gal"
property_name = "conc_proxy"
property_name = "msat_sum"
#property_name = "test"
Nsplits = [2, 4]
split_name = f"split_nan/{property_name}_split{Nsplit}"
split_names = [f"split_nan/{property_name}_split{Nsplit}" for Nsplit in Nsplits]

object2shuffle_list = [object2shuffle]*2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[r"2 percentiles"], loc='upper right', bbox_to_anchor=(1, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[r"4 percentiles"], loc='upper right', bbox_to_anchor=(1, 0.73))
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.95,1.065)
plt.legend()
#plt.savefig("figures/logM12.5-13_msat_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197058
# shotnoise:  130.52360745197058
# shotnoise:  130.52360745197058
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.15, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.15, 0.85))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[0]})"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[1]})"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm \tilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
#ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.95,1.065)
plt.legend()
plt.savefig("figures/logM12.5-13_msat_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197058
# shotnoise:  130.52360745197058
# shotnoise:  130.52360745197058
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
logM_name = "logM12-12.5"
logM_ps_name = ""
ps_type = "gal"
object2shuffle = "gal"
property_name = "conc_proxy"
property_name = "msat_sum"
#property_name = "test"
Nsplits = [2, 4]
split_name = f"split_nan/{property_name}_split{Nsplit}"
split_names = [f"split_nan/{property_name}_split{Nsplit}" for Nsplit in Nsplits]

object2shuffle_list = [object2shuffle]*2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[r"2 percentiles"], loc='upper right', bbox_to_anchor=(1, 0.85
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[r"4 percentiles"], loc='upper right', bbox_to_anchor=(1, 0.73))
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.95,1.065)
plt.legend()
#plt.savefig("figures/logM12-12.5_msat_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.1, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.1, 0.85))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[0]})"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[1]})"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm \tilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
#ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.95,1.065)
plt.legend()
#plt.savefig("figures/logM12-12.5_msat_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
logM_name = "logM11.5-12"
object2shuffle_list = ["gal", "cent_sat"]
property_name = "conc_proxy"
property_name2 = "msat_sum"
Nsplit = 4
split_name1 = f"split_nan/{property_name}_split{Nsplit}/{property_name2}_split{Nsplit}"
split_name2 = f"{property_name}_split{Nsplit}_{property_name2}_split{Nsplit}"
split_names = [split_name1, split_name2]

# %%
logM_name = "logM11.5-12"
object2shuffle_list = ["gal", "cent_sat"]
property_name = "conc_proxy"
property_name2 = "msat_sum"
Nsplit = 4
split_name1 = f"split_nan/{property_name}_split{Nsplit}/{property_name2}_split{Nsplit}"
split_name2 = f"{property_name}_split{Nsplit}_{property_name2}_split{Nsplit}"
split_names = [split_name1, split_name2]

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Random",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0, 1))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[1:2], labels=[r"Together"], loc='upper left', bbox_to_anchor=(0.6, 0.75
                                                                                            ))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[r"Separately"], loc='upper left', bbox_to_anchor=(0.6, 0.62))
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
ax.annotate("Split centrals and satellites \n" + r"by $\rm \widetilde{V}_{max}$ (4)"+ r" & $\rm M_{sat}$ (4)", (0.98,0.75), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.98,1.04)
plt.legend()
#plt.savefig("figures/logM11.5-12_together_vs_separate.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[r"M$\rm_{vir}$ only", r"$\rm M_{sat} (2)$", r"$\rm M_{sat} (8)$"], ratio_ylabel_list=["Random",""], return_color_leg=False, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
# leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"M$\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0, 1))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[1:2], labels=[r"Together"], loc='upper left', bbox_to_anchor=(0.6, 0.75
#                                                                                             ))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[r"Separately"], loc='upper left', bbox_to_anchor=(0.6, 0.62))
# ax.add_artist(leg)
# #ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
# #ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
# ax.annotate("Split centrals and satellites \n" + r"by $\rm \tilde{V}_{max}$ (4)"+ r" & $\rm M_{sat}$ (4)", (0.98,0.75), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

#plt.ylim(0.98,1.04)
plt.legend()
#plt.savefig("figures/logM11.5-12_vmax_only.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197072
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0, 0.85))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.55, 1), handlelength=1)
ax.add_artist(leg)

ax.annotate(r"$\widetilde{V}_{\rmmax}$ (4)"+ r" & $ M_{\rmsat}$ (4)", (0.95,0.73), xycoords="axes fraction", ha="right")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"Group"], loc='upper left', bbox_to_anchor=(0.55, 0.73), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"Cent & Sat"], loc='upper left', bbox_to_anchor=(0.55, 0.63), handlelength=1)
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm \tilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
#ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.98,1.04)
plt.legend()
#plt.savefig("figures/logM11.5-12_together_vs_separate.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197072
# shotnoise:  130.52360745197075
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
logM_name = "logM11-11.5"
logM_ps_name = ""
ps_type = "gal"
object2shuffle = "gal"
property_name = "conc_proxy"
#property_name = "msat_sum"
#property_name = "test"
Nsplits = [4, 100]
split_name = f"split_nan/{property_name}_split{Nsplit}"
split_names = [f"split_nan/{property_name}_split{Nsplit}" for Nsplit in Nsplits]

object2shuffle_list = [object2shuffle]*2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0, 1))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0, 0.85))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.6, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$\widetilde{{V}}_{{\rm max}}$ ({Nsplits[0]})"], loc='upper left', bbox_to_anchor=(0.6, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"$\widetilde{{V}}_{{\rm max}}$ ({Nsplits[1]})"], loc='upper left', bbox_to_anchor=(0.6, 0.73), handlelength=1)
ax.add_artist(leg)
#ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
#ax.annotate(r"Split by $\rm \tilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
#ax.annotate(r"Split by $\rm M_{sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.98,1.04)
plt.legend()
#plt.savefig("figures/logM11-11.5_vmax_split.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197066
# shotnoise:  130.52360745197063
# shotnoise:  130.52360745197066
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
Pks = []
for Pk in Pk_shuffled_list:
    Pks.append(Pk["power"].real[0])

# %%
Pk_mean = np.mean(Pks)
print(Pk_mean)
# Out:
# 11067.729182692305

# %%
Pks1 = []
for Pk in Pk_shuffled_list1:
    Pks1.append(Pk["power"].real[0])

# %%
Pk_mean1 = np.mean(Pks1)
print(Pk_mean1)
# Out:
# 11141.000961538462

# %%
Pk_tng = Pk_gal10["power"].real[0]

# %%
ratio0 = Pk_tng/Pk_mean
print(ratio0)
# Out:
# 1.013381909994766

# %%
ratio1 = Pk_tng/Pk_mean1
print(ratio1)
# Out:
# 1.006717132256018

# %%
(ratio1-1)/(ratio0-1)
# Out:
# 0.5019561675908149

# %%
color_leg = ps.residual_plot([Pk_sat10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property", ps_type=ps_type)#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()

solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.1, 1.05))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)
 
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[0]})"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"$M_{{\rm sat}}$ ({Nsplits[1]})"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
ax.add_artist(leg)
# leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[1:2], labels=[fr"{Nsplits[0]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.85
#                                                                                             ))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[fr"{Nsplits[1]} percentiles"], loc='upper left', bbox_to_anchor=(0.5, 0.73))
# ax.add_artist(leg)
# #ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
# #ax.annotate(r"Split by $\rm \tilde{V}_{max}$", (0.87,0.85), xycoords="axes fraction", ha="right")
# ax.annotate(r"Split by $M_{\rm sat}$", (0.9,0.85), xycoords="axes fraction", ha="right")

ax.annotate(f"{logM_name}", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${x:.2f}$'))
plt.ylim(0.875,1.26)
plt.legend()
#plt.savefig("figures/logM11-13.8_msat_sat_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132433
# shotnoise:  352.60039701132393
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
# leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[1:2], labels=[fr"$M_{{\mathrm{{sat}}}}$ (4)"], loc='upper left', bbox_to_anchor=(0.6, 0.85
#                                                                                             ))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[fr"various"], loc='upper left', bbox_to_anchor=(0.6, 0.73))
# ax.add_artist(leg)
# #ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
# #ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
# ax.annotate(r"Split by", (0.9,0.85), xycoords="axes fraction", ha="right")
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.1, 1.05))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ (4)"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"various"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
ax.add_artist(leg)

ax.annotate(f"logM11-13.8", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.92,1.14)
plt.legend()
#plt.savefig("figures/logM11-13.8_various_vs_msat_4.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197075
# shotnoise:  130.52360745197058
# shotnoise:  130.5236074519707
# 0
# 1
# 2

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
# leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[1:2], labels=[fr"$M_{{\mathrm{{sat}}}}$ (4)"], loc='upper left', bbox_to_anchor=(0.6, 0.85
#                                                                                             ))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[fr"various"], loc='upper left', bbox_to_anchor=(0.6, 0.73))
# ax.add_artist(leg)
# #ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
# #ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
# ax.annotate(r"Split by", (0.9,0.85), xycoords="axes fraction", ha="right")
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.1, 1.05))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
# leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ (4)"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[rf"various"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
# ax.add_artist(leg)

#ax.annotate(f"logM11-13.8", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.92,1.14)
plt.legend()
#plt.savefig("figures/logM11-13.8_shuffled.pdf", format="pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# is list
# shotnoise:  130.52360745197083
# shotnoise:  130.52360745197086
# 0

# %%
color_leg = ps.residual_plot([Pk_gal10], mean_of_seeds_lists=[Pk_shuffled_list, Pk_shuffled_list1, Pk_shuffled_list2], percentiles=[25,5], labels=[f"Shuffle {object2shuffle} {logM_name}", f"4 percentiles", f"100 percentiles", "Shuffled quartiles"], ratio_ylabel_list=["Shuffled",""], return_color_leg=True, tng_shuffle_type="property")#, bbox_to_anchor_color = (0,0.8))
#plt.ylim(0.97,1.06)
ax = plt.gca()
 
# leg = ax.legend(handles=color_leg, labels=["Shuffle by"+ "\n" + r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.1, 1))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[1:2], labels=[fr"$M_{{\mathrm{{sat}}}}$ (4)"], loc='upper left', bbox_to_anchor=(0.6, 0.85
#                                                                                             ))
# ax.add_artist(leg)
# leg = ax.legend(handles=color_leg[2:], labels=[fr"various"], loc='upper left', bbox_to_anchor=(0.6, 0.73))
# ax.add_artist(leg)
# #ax.annotate(r"M$\rm_{vir}$ &",(0.9,0.1), xycoords="axes fraction")
# #ax.annotate(r"Split by $\rm V_{max}/r_{max}$ (6)", (0.95,0.9), xycoords="axes fraction", ha="right")
# ax.annotate(r"Split by", (0.9,0.85), xycoords="axes fraction", ha="right")
solid_line = Line2D([],[],color="grey", linestyle="solid")
leg = ax.legend(handles=[solid_line], labels=[r"$P_{\rm TNG}/\bar{P}_{\rm Shuffled}$"], loc='upper left', bbox_to_anchor=(0.1, 1.05))
ax.add_artist(leg)
dot_line = Line2D([],[],color="grey", linestyle="dotted")
leg = ax.legend(handles=[dot_line], labels=[r"5 - 95% $(P_{\rm Shuffled})$"], loc='upper left', bbox_to_anchor=(0.1, 0.9))
ax.add_artist(leg)
leg = ax.legend(handles=color_leg, labels=[r"$M\rm_{vir}$ only"], loc='upper left', bbox_to_anchor=(0.65, 1), handlelength=1)
ax.add_artist(leg)

#ax.annotate(r"$\rm \widetilde{V}_{max}$", (0.65,0.73), xycoords="figure fraction")
leg = ax.legend(handles=color_leg[1:2], labels=[rf"$M_{{\rm sat}}$ (4)"], loc='upper left', bbox_to_anchor=(0.65, 0.85), handlelength=1)
ax.add_artist(leg)
leg = ax.legend(handles=color_leg[2:], labels=[rf"various"], loc='upper left', bbox_to_anchor=(0.65, 0.73), handlelength=1)
ax.add_artist(leg)

#ax.annotate(f"logM11-13.8", (0.9,0.1), xycoords="axes fraction", ha="right", weight="bold")

plt.ylim(0.92,1.14)
plt.legend()
#plt.savefig("figures/logM11-13.8_various_vs_msat_4.pdf", format="pdf", bbox_inches="tight")
# Out:
# is list
# No handles with labels found to put in legend.
# shotnoise:  130.52360745197083
# shotnoise:  130.52360745197078
# shotnoise:  130.52360745197058
# shotnoise:  130.52360745197086
# 0
# 1
# 2
