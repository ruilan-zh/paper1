# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rc("font", family="STIXGeneral", size=18)
plt.rcParams["mathtext.fontset"] = "stix"
plt.rcParams['figure.figsize'] = (2*10/3, 4)
plt.rcParams["legend.frameon"] = False


plt.rcParams["xtick.major.size"] = 5
plt.rcParams["ytick.major.size"] = 5
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["lines.linewidth"] = 2

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
with open(f"{odir}/snap40/mvir/ps-intensity-group_logM10.pickle", "rb") as f:
    Pk_mean_sum10 = pickle.load(f)
    Pk_sum10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
with open(f"{odir}/snap40/mvir/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
with open(f"{odir}/snap40/mvir/Nmesh2447/ps-intensity-sat_logM10.pickle", "rb") as f:
    Pk_mean_sat10 = pickle.load(f)
    Pk_sat10 = pickle.load(f)
print("shotnoise", Pk_sat10.attrs["shotnoise"])
# Out:
# shotnoise 352.60039701132393

# %%
logM_names = ["logMmax11", "logM11-11.5", "logM11.5-12", "logM12-12.5", "logM12.5-13", "logMmin13"]

# %%
logM_names = [""]

# %%
logM_names = ["logM12.5-13"]

# %%
object2shuffle = "cent"
interp="tsc"
Pk_shuffled_list_cents = []

for logM_name in logM_names:
    Pk_shuffled_list = []
    names_list = []
    seed_i = 0
    seed_f = 100
    n_seed = seed_f - seed_i

    power_list = []
    mean_intensities = []
    #odir = "ps_data"
    snapnum=40

    for seed in range(seed_i,seed_f):
        fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/sum_ps/shuffle_{object2shuffle}/{logM_name}/seed{seed}.pickle"
        
        if seed == 0:
            print(fname)
        with open(fname, "rb") as f:
            Pk_mean_gal_shuffled = pickle.load(f)
            #print("mean", Pk_mean_cent_shuffled)
            Pk_gal_shuffled = pickle.load(f)
            #print(Pk_mean_gal_shuffled)
            power_list.append(Pk_gal_shuffled["power"].real)

            mean_intensities.append(Pk_mean_gal_shuffled)

            print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
            Pk_shuffled_list.append(Pk_gal_shuffled)
            names_list.append(f"seed{seed}")


    power_arr = np.array(power_list)
    Pk_shuffled_list_cents.append(Pk_shuffled_list)
# Out:
# ../ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/sum_ps/shuffle_cent/logMmax11/seed0.pickle
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-d74462c32f79> in <module>()
#      20         if seed == 0:
#      21             print(fname)
# ---> 22         with open(fname, "rb") as f:
#      23             Pk_mean_gal_shuffled = pickle.load(f)
#      24             #print("mean", Pk_mean_cent_shuffled)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/sum_ps/shuffle_cent/logMmax11/seed0.pickle'

# %%
object2shuffle = "sat"
interp="tsc"
Pk_shuffled_list_sats = []

for logM_name in logM_names:
    Pk_shuffled_list = []
    names_list = []
    seed_i = 0
    seed_f = 100
    n_seed = seed_f - seed_i

    power_list = []
    mean_intensities = []
    #odir = "ps_data"
    snapnum=40

    for seed in range(seed_i,seed_f):
        fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_{object2shuffle}/{logM_name}/seed{seed}.pickle"
        
        if seed == 0:
            print(fname)
        with open(fname, "rb") as f:
            Pk_mean_gal_shuffled = pickle.load(f)
            #print("mean", Pk_mean_cent_shuffled)
            Pk_gal_shuffled = pickle.load(f)
            #print(Pk_mean_gal_shuffled)
            power_list.append(Pk_gal_shuffled["power"].real)

            mean_intensities.append(Pk_mean_gal_shuffled)

            print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
            Pk_shuffled_list.append(Pk_gal_shuffled)
            names_list.append(f"seed{seed}")


    power_arr = np.array(power_list)
    Pk_shuffled_list_sats.append(Pk_shuffled_list)
# Out:
# ../ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/gal_ps/shuffle_sat//seed0.pickle
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083
# shotnoise 130.52360745197083

# %%
object2shuffle = "sat"
interp="tsc"
Pk_shuffled_list_sats_group = []

for logM_name in logM_names:
    Pk_shuffled_list = []
    names_list = []
    seed_i = 0
    seed_f = 10
    n_seed = seed_f - seed_i

    power_list = []
    mean_intensities = []
    #odir = "ps_data"
    snapnum=40

    for seed in range(seed_i,seed_f):
        fname = f"{odir}/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/group_ps/shuffle_{object2shuffle}/{logM_name}/seed{seed}.pickle"
        
        if seed == 0:
            print(fname)
        with open(fname, "rb") as f:
            Pk_mean_gal_shuffled = pickle.load(f)
            #print("mean", Pk_mean_cent_shuffled)
            Pk_gal_shuffled = pickle.load(f)
            #print(Pk_mean_gal_shuffled)
            power_list.append(Pk_gal_shuffled["power"].real)

            mean_intensities.append(Pk_mean_gal_shuffled)

            print("shotnoise", Pk_gal_shuffled.attrs["shotnoise"])
            Pk_shuffled_list.append(Pk_gal_shuffled)
            names_list.append(f"seed{seed}")


    power_arr = np.array(power_list)
    Pk_shuffled_list_sats_group.append(Pk_shuffled_list)
# Out:
# ../ps_data/snap40/mvir/shuffled/logM10_dlogM0.1/changed_bins/group_ps/shuffle_sat//seed0.pickle
# shotnoise 282.78588655801343
# shotnoise 283.97045650686476
# shotnoise 284.00588994993063
# shotnoise 280.76698572683057
# shotnoise 282.6215345231493
# shotnoise 283.0311857939318
# shotnoise 281.98845462001145
# shotnoise 284.0638691708774
# shotnoise 283.4124928627355
# shotnoise 280.2072128629623

# %%
ps.compare_ps_plot([Pk_gal10], mean_of_seeds_lists=Pk_shuffled_list_sats)
# Out:
# is list
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-24aabb6c707c> in <module>()
# ----> 1 ps.compare_ps_plot([Pk_gal10], mean_of_seeds_lists=Pk_shuffled_list_sats)
#
# ~/MyHaloPS.py in compare_ps_plot(Pks1, labels, ratio_ylabel, ratio_ylabel_list, mean, var, log, dim, others, noise, fontsize, ratio_fontsize, color_legend, grey_legend, legend_fontsize, ylim1, ylim2, ylim3, error_band, shotnoise_ps, shotnoise_subtracted_ps, xlim, grey_shading, residuals_only, separate_ratio_panels, bbox_to_anchor_grey, bbox_to_anchor_color, marker_size, ncore, nyquist_list, total_ps, len_k, knyq, return_solid_leg, start_k, mean_of_seeds_lists, mean_of_seeds_reverse, percentiles, return_grey_leg, clus_ps_error, dots4group, toy_model, color_list, ax, create_fig)
#    1337                 else:
#    1338                     if len(mean_list) > 1:
# -> 1339                         ratio_std2 = np.std(power_arr2[:len_k]/power_ref[:len_k], axis=0)[:len_k]
#    1340                         shot_ratio_std2 = np.std(shot_list2/shot_ref)
#    1341                         clus_ratio_std2 = np.std(clus_list2[:len_k]/clus_ref[:len_k], axis=0)[:len_k]
#
# ValueError: operands could not be broadcast together with shapes (100,689) (344,)

# %%
ps.compare_ps_plot([ Pk_shuffled_list_sats[0][0], Pk_shuffled_list_sats_group[0][0]])
# Out:
# shotnoise:  130.52360745197083
# shotnoise:  282.78588655801343
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1501: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([ Pk_shuffled_list_sats_group[0][0]], mean_of_seeds_lists=Pk_shuffled_list_sats)
# Out:
# is list
# shotnoise:  130.5236074519708
# shotnoise:  282.78588655801343
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1501: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
idir = "/cosma7/data/dp004/dc-zhan5/shuffled/logM10_dlogM0.1_snap40/changed_bins/group_ps/shuffle_sat/logM12.5-13"
mass1, x, y, z, sfr1 = np.loadtxt(f"{idir}/seed0.txt", unpack=True)

# %%
idir = "/cosma7/data/dp004/dc-zhan5/shuffled/logM10_dlogM0.1_snap40/changed_bins/gal_ps/shuffle_sat/logM12.5-13"
mass2, x2, y2, z2, sfr2 = np.loadtxt(f"{idir}/seed0.txt", unpack=True)

# %%
def compute_uk2(Pk_gal10, Pk_sum10):
    ks_tng = Pk_gal10["k"]


    tot = (Pk_gal10["power"]-(Pk_sum10["power"]-Pk_sum10.attrs["shotnoise"]))
    
    shot_gal = Pk_gal10.attrs["shotnoise"]
    shot_halo = Pk_sum10.attrs["shotnoise"]
    uk2 = (tot - shot_gal)/(shot_halo - shot_gal)
    return uk2

# %%
orig = compute_uk2(Pk_gal10, Pk_sum10)
shuffled = compute_uk2(Pk_shuffled_list_sats[0][5], Pk_shuffled_list_sats_group[0][5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3b422242ed2d> in <module>()
# ----> 1 orig = compute_uk2(Pk_gal10, Pk_sum10)
#       2 shuffled = compute_uk2(Pk_shuffled_list_sats[0][5], Pk_shuffled_list_sats_group[0][5])
#
# NameError: name 'compute_uk2' is not defined

# %%
ks = Pk_gal10["k"]
logks = np.log10(ks)

# %%
plt.plot(logks, orig)
plt.plot(logks, shuffled)
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(logks, orig/shuffled)
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
ps.compare_ps_plot([Pk_gal10], mean_of_seeds_lists=Pk_shuffled_list_sats)
# Out:
# is list
# shotnoise:  130.5236074519708
# shotnoise:  130.52360745197086

# %%
plt.plot(logks, Pk_sum10["power"]/Pk_shuffled_list_sats[0][0]["power"])
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
orig_2halo = Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"]
shuffled_2halo = Pk_shuffled_list_sats_group[0][0]["power"].real - Pk_shuffled_list_sats_group[0][0].attrs["shotnoise"]

# %%
orig_1halo = Pk_gal10["power"].real - orig_2halo
shuffled_1halo = Pk_shuffled_list_sats[0][0]["power"].real - shuffled_2halo

# %%
plt.plot(logks, [Pk_sum10.attrs["shotnoise"]/Pk_shuffled_list_sats_group[0][0].attrs["shotnoise"]]*len(logks))

# %%
plt.plot(logks, orig_2halo/shuffled_2halo)
plt.ylim(1,1.3)
# Out:
# (1.0, 1.3)

# %%
plt.plot(logks, shuffled_1halo, label="shuffled")
plt.plot(logks, orig_1halo, label="TNG")

plt.legend()

# %%
plt.plot(logks, orig_1halo/shuffled_1halo)
plt.ylim(1,1.3)
# Out:
# (1.0, 1.3)

# %%
plt.plot(logks, (Pk_sum10["power"]-Pk_sum10.attrs["shotnoise"])/(Pk_shuffled_list_sats_group[0][0]["power"]-Pk_shuffled_list_sats[0][0]["power"]))
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
