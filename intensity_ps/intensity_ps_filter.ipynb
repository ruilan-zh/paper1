# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
    
    
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
filter_type = "top_hat"

# %%
filter_type = "gaussian"

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_mean1 = pickle.load(f)
    Pk_sum10 = pickle.load(f)
print("shotnoise", Pk1.attrs["shotnoise"])
# Out:
# shotnoise 303.76791688190417

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/{filter_type}_filter/r=0.05.pickle", "rb") as f:
    Pk_mean1 = pickle.load(f)
    Pk1 = pickle.load(f)
print("shotnoise", Pk1.attrs["shotnoise"])
# Out:
# shotnoise 303.76791688190417

# %%
#odir = "ps_data"
with open(f"{odir}/snap40/mvir/{filter_type}_filter/r=0.3.pickle", "rb") as f:
    Pk_mean2 = pickle.load(f)
    Pk2 = pickle.load(f)
print("shotnoise", Pk2.attrs["shotnoise"])
# Out:
# shotnoise 303.76791688190417

# %%
#odir = "ps_data"
with open(f"{odir}/snap40/mvir/{filter_type}_filter/r=0.1.pickle", "rb") as f:
    Pk_mean2 = pickle.load(f)
    Pk2 = pickle.load(f)
print("shotnoise", Pk2.attrs["shotnoise"])
# Out:
# shotnoise 303.76791688190417

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
ps.compare_ps_plot([Pk_sum10, Pk1, Pk2], labels=["TNG", "$a = 0.05\ \mathrm{Mpc\ h^{-1}}$", "$a = 0.3\ \mathrm{Mpc\ h^{-1}}$"], ratio_ylabel_list=["Halo", "Gaussian"], bbox_to_anchor_grey=(0.02,1), bbox_to_anchor_color=(0.25,0.5), shotnoise_subtracted_ps=True, shotnoise_ps=False, color_list=["goldenrod"] + ["Dodgerblue"] + ["purple"] )
plt.ylim(0.95,1.02)
#plt.savefig("../figures/gaussian_filter_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  304.0903879154701
# shotnoise:  303.76791688190417
# shotnoise:  303.76791688190417
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.95, 1.02)
