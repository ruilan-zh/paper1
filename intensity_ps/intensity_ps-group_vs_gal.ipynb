# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rc("font", family="STIXGeneral", size=18)
plt.rcParams["mathtext.fontset"] = "stix"
plt.rcParams['figure.figsize'] = (2*10/3, 4)
plt.rcParams["legend.frameon"] = False


plt.rcParams["xtick.major.size"] = 5
plt.rcParams["ytick.major.size"] = 5
plt.rcParams["ytick.minor.visible"] = True
plt.rcParams["xtick.minor.visible"] = True
plt.rcParams["xtick.top"] = True
plt.rcParams["ytick.right"] = True
plt.rcParams["lines.linewidth"] = 2

# %% [markdown]
# # 3D halo power spectrum

# %%
odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_all.pickle", "rb") as f:
    Pk_mean_gal_all = pickle.load(f)
    Pk_gal_all = pickle.load(f)

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.52360745197086

# %%
#odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sum_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_sum10 = pickle.load(f)

# %%
#odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)

# %%
#odir = "ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-sat_logM10.pickle", "rb") as f:
    Pk_mean_sat10 = pickle.load(f)
    Pk_sat10 = pickle.load(f)

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
ps.compare_ps_plot([Pk_gal10, Pk_cent10, Pk_sat10], labels=["Galaxy", "Central", "Satellite"], ratio_ylabel_list=["Galaxy","Component"], bbox_to_anchor_grey=(0.4,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=True, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5])
#plt.savefig("../figures/gal_cent_sat_ps.pdf", format="pdf", bbox_inches="tight")
#plt.ylim(0.5,1.1)
# Out:
# shotnoise:  130.38519438706473
# shotnoise:  202.34259177562294
# shotnoise:  352.60039701132393
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1471: RuntimeWarning: invalid value encountered in log10
#   #print(y3)

# %%
ps.compare_ps_plot([Pk_gal10, Pk_cent10], labels=["Galaxy", "Central", "Satellite"], ratio_ylabel_list=["Galaxy","Central"], bbox_to_anchor_grey=(0.65,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5])
#plt.savefig("../figures/gal_cent_ps.pdf", format="pdf", bbox_inches="tight")
plt.ylim(0.6,1.6)
# Out:
# shotnoise:  130.52360745197086
# shotnoise:  201.65155090472237
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.6, 1.6)

# %%
ps.compare_ps_plot([Pk_sum10, Pk_cent10], labels=["Halo", "Central", "Satellite"], ratio_ylabel_list=["Galaxy","Central"], bbox_to_anchor_grey=(0.65,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5])
plt.ylim(0.6,1.1)
#plt.savefig("../figures/halo_cent_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  304.0903879154701
# shotnoise:  201.65155090472237
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1487: RuntimeWarning: invalid value encountered in log10
#   if residuals_only is False:
# (0.6, 1.1)

# %%
ps.compare_ps_plot([Pk_sum10, Pk_cent10], labels=["Halo", "No satellites", "Satellite"], ratio_ylabel_list=["\mathrm{Halo}","\mathrm{Central}"], bbox_to_anchor_grey=(0.65,0.9), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5], residuals_only=True)
#plt.savefig("../figures/halo_cent_ps.pdf", format="pdf", bbox_inches="tight")
plt.ylim(0.6,1.0)
# Out:
# shotnoise:  304.0903879154701
# shotnoise:  201.65155090472237
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1487: RuntimeWarning: invalid value encountered in log10
#   if residuals_only is False:
# (0.6, 1.0)

# %%
ps.compare_ps_plot([Pk_sum10, Pk_gal10, Pk_cent10], labels=["Halo", "Galaxy", "Central"], ratio_ylabel_list=["Galaxy","Central"], bbox_to_anchor_grey=(0.65,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, shotnoise_ps=False, dots4group=True, color_list = ["navy"] + ["lightpink"] + ["purple"])
#plt.savefig("../figures/gal_halo_cent_ps.pdf", format="pdf", bbox_inches="tight")
#plt.ylim(0.6,1.6)
# Out:
# shotnoise:  304.0903879154701
# shotnoise:  130.52360745197086
# shotnoise:  201.65155090472237
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
snapnum = 72

# %%
odir = "../ps_data"
with open(f"{odir}/snap{snapnum}/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 117.24942527334497

# %%
#odir = "ps_data"
with open(f"{odir}/snap{snapnum}/mvir/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)

# %%
print(Pk_mean_gal10)
# Out:
# 13.347169964018947

# %%
ik = 0

# %%
Pk_cent10["power"].real[ik]/Pk_gal10["power"].real[ik]
# Out:
# 0.6498346628485716

# %%
Pk_mean_cent10/Pk_mean_gal10
# Out:
# 0.6362535007908506

# %%
odir = "../ps_data"
with open(f"{odir}/snap{snapnum}/mvir/z=1.5_distances/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])

#odir = "ps_data"
with open(f"{odir}/snap{snapnum}/mvir/z=1.5_distances/ps-intensity-cent_logM10.pickle", "rb") as f:
    Pk_mean_cent10 = pickle.load(f)
    Pk_cent10 = pickle.load(f)
Pk_cent10["power"].real[ik]/Pk_gal10["power"].real[ik]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-184-804652c7cc32> in <module>()
#       1
#       2 odir = "../ps_data"
# ----> 3 with open(f"{odir}/snap{snapnum}/mvir/z=1.5_distances/ps-intensity-gal_logM10.pickle", "rb") as f:
#       4     Pk_mean_gal10 = pickle.load(f)
#       5     Pk_gal10 = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../ps_data/snap72/mvir/z=1.5_distances/ps-intensity-gal_logM10.pickle'

# %%
ps.compare_ps_plot([Pk_gal10, Pk_cent10], labels=["Galaxy", "Central", "Satellite"], residuals_only=True, ratio_ylabel_list=["Galaxy","Central"], bbox_to_anchor_grey=(0.1,0.8), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5])

plt.ylim(0.6,1.6)
ax=plt.gca()
ax.annotate("$\mathbf{z \sim 0.4}$", (0.85,0.6), xycoords="axes fraction", ha="right", weight="bold")
#plt.savefig(f"../figures/gal_cent_ps_z0.4.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  117.24942527334497
# shotnoise:  170.98749968921453
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# Text(0.85, 0.6, '$\\mathbf{z \\sim 0.4}$')

# %%
np.log10(Pk_cent10["k"][:10])
# Out:
# array([-1.36222777, -1.06018157, -0.85884198, -0.7253186 , -0.62645781,
#        -0.54257553, -0.47286541, -0.41408804, -0.36101929, -0.31339319])

# %%
(Pk_cent10["power"].real/Pk_gal10["power"].real)[:10]
# Out:
# array([0.64983466, 0.70435787, 0.68774189, 0.65852442, 0.65153678,
#        0.68858814, 0.6752852 , 0.66160863, 0.66262174, 0.67845338])

# %%
ps.compare_ps_plot([Pk_gal10, Pk_cent10], labels=["Galaxy", "Central", "Satellite"], residuals_only=True, ratio_ylabel_list=["Galaxy","Central"], bbox_to_anchor_grey=(0.1,0.75), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=False, dots4group=True, color_list=palette_tab10[3:4] + palette_tab10[2:3] + palette_tab10[4:5])

plt.ylim(0.6,1.6)
ax=plt.gca()
ax.annotate("$\mathbf{z \sim 0.4}$", (0.85,0.6), xycoords="axes fraction", ha="right", weight="bold")
#plt.savefig(f"../figures/gal_cent_ps_z3.pdf", format="pdf", bbox_inches="tight")

# %%
Pk_cent10["power"][0]/Pk_gal10["power"][0]
# Out:
# (0.6785003412071017+0j)

# %%
importlib.reload(ps)
# Out:
# <module 'MyHaloPS' from '/cosma/home/dp004/dc-zhan5/MyHaloPS.py'>

# %%
import matplotlib.ticker as ticker

# %%
ps.compare_ps_plot([Pk_gal10, Pk_sum10], labels=["Galaxy", "Halo"], ratio_ylabel_list=["Galaxy","Halo"], bbox_to_anchor_grey=(0.4,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=True, dots4group=True)
plt.ylim(0.2,2.45)
ax = plt.gca()
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${x:.2f}$'))

#plt.savefig("../figures/gal_vs_halo_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  130.5236074519707
# shotnoise:  304.09038791547044
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1467: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal10, Pk_sum10], labels=["Galaxy", "Group"], ratio_ylabel_list=["Galaxy","Group"], bbox_to_anchor_grey=(0.4,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=True, dots4group=True)
plt.ylim(0.2,2.45)
#plt.savefig("../figures/gal_vs_group_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  130.5236074519707
# shotnoise:  304.09038791547044
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1467: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)

# %%
ps.compare_ps_plot([Pk_gal10, Pk_sum10], labels=["Galaxy", "Group"], ratio_ylabel_list=["Galaxy","Group"], bbox_to_anchor_grey=(0.4,0.45), bbox_to_anchor_color=(0,1), shotnoise_subtracted_ps=True, dots4group=True)
plt.ylim(0.2,2.45)
#plt.savefig("../figures/gal_vs_group_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# shotnoise:  130.52360745197086
# shotnoise:  304.0903879154701
# /cosma/home/dp004/dc-zhan5/MyHaloPS.py:1482: RuntimeWarning: invalid value encountered in log10
#   y3 = np.log10(y)
# (0.2, 2.45)

# %%
(Pk_sum10["power"].real/Pk_gal10["power"].real)[:15]
# Out:
# array([0.99989444, 0.99951578, 0.99961387, 1.00000303, 1.00101271,
#        1.00014799, 0.99990835, 1.00172576, 1.00425329, 1.00308447,
#        1.00363478, 1.00583237, 1.00604923, 1.00894536, 1.01221548])

# %%
((Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])/(Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:15]
# Out:
# array([0.98423584, 0.97174307, 0.94866457, 0.93208679, 0.89042163,
#        0.85658295, 0.82858145, 0.78780759, 0.74824936, 0.71176636,
#        0.67149332, 0.6363229 , 0.60494576, 0.57128228, 0.53738091])

# %%
np.log10(ks[:15])
# Out:
# array([-1.36238137, -1.06033514, -0.85899556, -0.72547219, -0.62661139,
#        -0.54272912, -0.473019  , -0.41424163, -0.36117288, -0.31354678,
#        -0.27102314, -0.23226579, -0.19665425, -0.16393475, -0.13327703])

# %%
ks = Pk_gal10["k"]
coef = ks**3 / (2 * np.pi **2)

# %%
color_list1 = palette_tab10[3:4] + palette_tab10[1:2]

# %%
color_list1 = palette_tab10[3:4] + ["goldenrod"]

# %%
color_list2 = ["DodgerBlue", "purple"]

# %%
len_k = 344

# %%
plt.scatter(np.log10(ks)[:len_k], np.log10((coef*Pk_sum10["power"].real)- (coef*Pk_sum10.attrs["shotnoise"].real))[:len_k], s=1)
#plt.ylim(0,10)
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
color_list1 = palette_tab10[0:1] + palette_tab10[1:2]

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
len_k = len(ks)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", linestyle="dashdot", color=color_list1[1],linewidth=1)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10.attrs["shotnoise"]))[:len_k], label="TNG clustering (gal)", linestyle="dashdot", color=color_list1[0],linewidth=1)


# plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

label_list = ["Galaxy", "Halo"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
    solid_lines.append(solid_line)

first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
ax.add_artist(first_legend)


color="grey"
total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\rm tot} - P_{\rm shot}$", linewidth=4)
shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm halo}$", r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group} -  P_{\rm shot}^{\rm gal}$"]
# solid_lines = []
# for i, label in enumerate(label_list):
#     solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
#     solid_lines.append(solid_line)
# second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
# ax.add_artist(second_legend)

frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=2
#plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=palette_tab10[3] , linestyle="dashed")
plt.plot([-1.6, 2.5], [1,1], linestyle=(5, (20/linewidth1, 6/linewidth1)), c=palette_tab10[0], zorder=0, linewidth=linewidth1)
#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 15
#plt.plot(np.log10(ks[:iend]), (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=palette_tab10[1])
plt.plot(np.log10(ks), [Pk_sum10.attrs["shotnoise"]/Pk_gal10.attrs["shotnoise"]]*len(ks), label="TNG clustering (group)", linestyle="dashdot", color=color_list1[1],linewidth=2)

plt.plot(np.log10(ks), (Pk_sum10["power"].real)/(Pk_gal10["power"].real), linestyle="solid", color=palette_tab10[1] )



plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
plt.ylabel(r"$P^{\mathrm{halo}}/P^{\mathrm{gal}}$")
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
#plt.ylim(0.97, 1.005)
#plt.savefig("../figures/gal_vs_halo_no_clus.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log10
#   if __name__ == '__main__':

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
len_k = len(ks)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", linestyle="dashdot", color=color_list1[1],linewidth=1)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10.attrs["shotnoise"]))[:len_k], label="TNG clustering (gal)", linestyle="dashdot", color=color_list1[0],linewidth=1)


# plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

label_list = ["Galaxy", "Halo"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
    solid_lines.append(solid_line)

first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
ax.add_artist(first_legend)


color="grey"
total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\rm tot} - P_{\rm shot}$", linewidth=4)
shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group}$", r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group} -  P_{\rm shot}^{\rm gal}$"]
# solid_lines = []
# for i, label in enumerate(label_list):
#     solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
#     solid_lines.append(solid_line)
# second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
# ax.add_artist(second_legend)

frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=palette_tab10[3] , linestyle="dashed")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 15
#plt.plot(np.log10(ks[:iend]), (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=palette_tab10[1])
plt.plot(np.log10(ks), [Pk_sum10.attrs["shotnoise"]/Pk_gal10.attrs["shotnoise"]]*len(ks), label="TNG clustering (group)", linestyle="dashdot", color=color_list1[1],linewidth=2)

plt.plot(np.log10(ks), (Pk_sum10["power"].real)/(Pk_gal10["power"].real), linestyle="solid", color=palette_tab10[1] )



plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
plt.ylabel(r"$P^{\mathrm{halo}}/P^{\mathrm{gal}}$")
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
#plt.ylim(0.97, 1.005)
#plt.savefig("../figures/gal_vs_group_no_clus.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in log10
#   if __name__ == '__main__':
# (-1.55, 1.3)

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[0], linewidth=1)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[1], linewidth=1)



plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")
plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[1], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

label_list = ["Galaxy", "Group"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
    solid_lines.append(solid_line)

first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
ax.add_artist(first_legend)


color="grey"
total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\mathrm{clus}} = P_{\rm tot} - P_{\rm shot}$", linewidth=4)
shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group}$", r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group} -  P_{\rm shot}^{\rm gal}$"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
ax.add_artist(second_legend)

frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=color_list1[1], linestyle="dotted")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 15
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[0])
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[1])

#plt.plot(np.log10(ks), coef * Pk_gal10["power"]/(pkgal2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[0])
#plt.plot(np.log10(ks), coef * Pk_sum10["power"][:iend]/(pksum2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks),coef * (Pk_gal10["power"]-Pk_gal10.attrs["shotnoise"])/(pkgal2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
#plt.plot(np.log10(ks), coef * (Pk_sum10["power"][:iend]-Pk_sum10.attrs["shotnoise"])/(pksum2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (group)", color=color_list1[1])
#plt.plot(np.log10(ks), normed_Pk_matter_nl/normed_Pk_matter_lin, label="nonlinear x 4", color = color_list2[1], linestyle="dotted")




plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
plt.ylabel(r"$P_{\mathrm{clus}}$ ratio")
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
plt.ylim(0.97, 1.005)
#plt.savefig("../figures/one_halo_term.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in log10
#   from ipykernel import kernelapp as app
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in log10
#   app.launch_new_instance()

# %%
np.log10(ks[:6])
# Out:
# array([-1.36238137, -1.06033514, -0.85899556, -0.72547219, -0.62661139,
#        -0.54272912])

# %%
new_shot = np.zeros(len(ks))

# %%
np.log10(ks[50])
# Out:
# 0.4040083950382012

# %%
#for i in range(6):
#    new_shot[i] = Pk_sum10.attrs["shotnoise"]
for i in range(50,len(ks)):
    new_shot[i] = Pk_gal10.attrs["shotnoise"]

# %%
new_halo = np.zeros(len(ks))
for i in range(6):
    new_halo[i] = Pk_sum10["power"].real[i]

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - new_shot))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-new_shot)))[:len_k], label="TNG total")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])-Pk_gal10.attrs["shotnoise"]))[:len_k], label="TNG total")

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10.attrs["shotnoise"])))[:len_k], label="TNG total")

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10["power"].real)))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"])))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]- (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"]))))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10.attrs["shotnoise"])))[:len_k], label="TNG total")

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10["power"].real)))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_sum10.attrs["shotnoise"])))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])))[:len_k], label="TNG total")
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"]) - new_shot))[:len_k], label="TNG total")

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * ((Pk_gal10["power"].real)))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - new_halo))[:len_k], label="TNG total")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])))[:len_k], label="TNG total")

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"]) - Pk_gal10.attrs["shotnoise"]))[:len_k], label="TNG total")

# %%
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - (Pk_sum10["power"].real)))[:len_k], label="TNG total")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[0], linewidth=1)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[1], linewidth=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real - new_shot))[:len_k], label="TNG total")


plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")
plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[1], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

label_list = ["Galaxy", "Group"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
    solid_lines.append(solid_line)

first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
ax.add_artist(first_legend)


color="grey"
total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\mathrm{clus}} = P_{\rm tot} - P_{\rm shot}$", linewidth=4)
shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group}$", r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group} -  P_{\rm shot}^{\rm gal}$"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
ax.add_artist(second_legend)

frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=color_list1[1], linestyle="dotted")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 15
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[0])
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[1])

#plt.plot(np.log10(ks), coef * Pk_gal10["power"]/(pkgal2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[0])
#plt.plot(np.log10(ks), coef * Pk_sum10["power"][:iend]/(pksum2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks),coef * (Pk_gal10["power"]-Pk_gal10.attrs["shotnoise"])/(pkgal2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
#plt.plot(np.log10(ks), coef * (Pk_sum10["power"][:iend]-Pk_sum10.attrs["shotnoise"])/(pksum2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (group)", color=color_list1[1])
#plt.plot(np.log10(ks), normed_Pk_matter_nl/normed_Pk_matter_lin, label="nonlinear x 4", color = color_list2[1], linestyle="dotted")




plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
plt.ylabel(r"$P_{\mathrm{clus}}$ ratio")
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
plt.ylim(0.97, 1.005)
#plt.savefig("../figures/one_halo_term.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in log10
#   app.launch_new_instance()
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in log10
# (0.97, 1.005)

# %%
iend = 500

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[0], linewidth=1)
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[1], linewidth=1)



plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")
plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[1], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

# label_list = ["Galaxy", "Group"]
# solid_lines = []
# for i, label in enumerate(label_list):
#     solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
#     solid_lines.append(solid_line)

# first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
# ax.add_artist(first_legend)


# color="grey"
# total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
# shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\mathrm{clus}} = P_{\rm tot} - P_{\rm shot}$", linewidth=4)
# shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

# leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
# leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
# ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")


label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm gal}$", 
             r"$P_{\rm tot}^{\rm group} - P_{\rm shot}^{\rm group}$" ]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
    
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor = (0,1), ncol=2, columnspacing=0.8)
ax.add_artist(second_legend)

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group}$", 
              r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group} -  P_{\rm shot}^{\rm gal}$"]
             
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
#second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor = (0,0.85))
ax.add_artist(second_legend)       


frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=color_list1[1], linestyle="dotted")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 30
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list1[0])

plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[0])
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[1])

#plt.plot(np.log10(ks), coef * Pk_gal10["power"]/(pkgal2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[0])
#plt.plot(np.log10(ks), coef * Pk_sum10["power"][:iend]/(pksum2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks),coef * (Pk_gal10["power"]-Pk_gal10.attrs["shotnoise"])/(pkgal2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
#plt.plot(np.log10(ks), coef * (Pk_sum10["power"][:iend]-Pk_sum10.attrs["shotnoise"])/(pksum2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (group)", color=color_list1[1])
#plt.plot(np.log10(ks), normed_Pk_matter_nl/normed_Pk_matter_lin, label="nonlinear x 4", color = color_list2[1], linestyle="dotted")



plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
#plt.ylabel(r"$P_{\mathrm{clus}}$ ratio")
plt.ylabel(r"$\rm \frac{Galaxy}{Group}$", fontsize=20)
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
plt.ylim(0.95, 1.05)
#plt.savefig("../figures/shotnoise_subtracted_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in log10
#   from ipykernel import kernelapp as app
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in log10
#   app.launch_new_instance()

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[0], linewidth=1)
# plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[1], linewidth=1)



plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")
plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[1], linestyle="dotted")

#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

# label_list = ["Galaxy", "Group"]
# solid_lines = []
# for i, label in enumerate(label_list):
#     solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
#     solid_lines.append(solid_line)

# first_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor=(0.4,1))
# ax.add_artist(first_legend)


# color="grey"
# total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
# shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\mathrm{clus}} = P_{\rm tot} - P_{\rm shot}$", linewidth=4)
# shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

# leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
# leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
# ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")


label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm gal}$", 
             r"$P_{\rm tot}^{\rm halo} - P_{\rm shot}^{\rm halo}$" ]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
    
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor = (0,1), ncol=2, columnspacing=0.8)
ax.add_artist(second_legend)

label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm halo}$", 
              r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm halo} -  P_{\rm shot}^{\rm gal}$"]
             
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)
#second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,-0.05))
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="upper left", bbox_to_anchor = (0,0.85))
ax.add_artist(second_legend)       


frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=color_list1[1], linestyle="dotted")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 30
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list1[0])

plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[0])
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"] - Pk_gal10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[1])

#plt.plot(np.log10(ks), coef * Pk_gal10["power"]/(pkgal2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[0])
#plt.plot(np.log10(ks), coef * Pk_sum10["power"][:iend]/(pksum2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks),coef * (Pk_gal10["power"]-Pk_gal10.attrs["shotnoise"])/(pkgal2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
#plt.plot(np.log10(ks), coef * (Pk_sum10["power"][:iend]-Pk_sum10.attrs["shotnoise"])/(pksum2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (group)", color=color_list1[1])
#plt.plot(np.log10(ks), normed_Pk_matter_nl/normed_Pk_matter_lin, label="nonlinear x 4", color = color_list2[1], linestyle="dotted")



plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
#plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
#plt.ylabel(r"$P_{\mathrm{clus}}$ ratio")
plt.ylabel(r"$\rm \frac{Galaxy}{Halo}$", fontsize=20)
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
plt.ylim(0.95, 1.05)
#plt.savefig("../figures/shotnoise_subtracted_ps.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in log10
#   from ipykernel import kernelapp as app
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in log10
#   app.launch_new_instance()

# %%
np.log10(ks)[:30]
# Out:
# array([-1.36238137, -1.06033514, -0.85899556, -0.72547219, -0.62661139,
#        -0.54272912, -0.473019  , -0.41424163, -0.36117288, -0.31354678,
#        -0.27102314, -0.23226579, -0.19665425, -0.16393475, -0.13327703,
#        -0.10463917, -0.07807909, -0.05288839, -0.02885982, -0.00633747,
#         0.01517543,  0.03567356,  0.05510273,  0.07391712,  0.09187437,
#         0.10904308,  0.12551484,  0.14142312,  0.15695358,  0.17190578])

# %%
(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:30]
# Out:
# array([10911.74615055,  6078.25253972,  3234.07921436,  2382.02800639,
#         1394.68450433,  1035.27537761,   839.57676936,   636.75021347,
#          502.24950039,   420.84936412,   347.57369467,   294.09516882,
#          257.18793329,   220.34171146,   188.60644996,   168.46605646,
#          136.20754641,   126.58600373,   102.33578728,    95.55696562,
#           81.38086629,    68.30303272,    61.42131338,    51.58252443,
#           44.07593702,    33.8847134 ,    28.92804574,    21.67637545,
#           18.73248707,    12.74070721])

# %%
(Pk_sum10["power"].real - Pk_sum10.attrs["shotnoise"])[:30]
# Out:
# array([10910.56225632,  6075.16207919,  3232.71302118,  2382.03613647,
#         1396.40487071,  1035.47358425,   839.47195439,   638.37387531,
#          505.67909878,   423.08541604,   349.94234827,   297.58400751,
#          260.58323583,   225.0329428 ,   194.62497933,   176.99891382,
#          143.6059508 ,   136.29157031,   113.09546837,   107.19942894,
#           93.52392185,    81.71061398,    75.68721651,    65.83897541,
#           58.82744467,    51.95441306,    47.55937255,    40.29978233,
#           37.74002851,    34.69543031])

# %%
(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:50]
# Out:
# array([ 1.09117462e+04,  6.07825254e+03,  3.23407921e+03,  2.38202801e+03,
#         1.39468450e+03,  1.03527538e+03,  8.39576769e+02,  6.36750213e+02,
#         5.02249500e+02,  4.20849364e+02,  3.47573695e+02,  2.94095169e+02,
#         2.57187933e+02,  2.20341711e+02,  1.88606450e+02,  1.68466056e+02,
#         1.36207546e+02,  1.26586004e+02,  1.02335787e+02,  9.55569656e+01,
#         8.13808663e+01,  6.83030327e+01,  6.14213134e+01,  5.15825244e+01,
#         4.40759370e+01,  3.38847134e+01,  2.89280457e+01,  2.16763754e+01,
#         1.87324871e+01,  1.27407072e+01,  7.63495978e+00,  7.33355585e+00,
#        -1.44645270e+00, -3.86546321e+00, -6.18394861e+00, -8.95451019e+00,
#        -1.23563093e+01, -1.46855818e+01, -1.95842066e+01, -2.12668189e+01,
#        -2.41772818e+01, -2.45796901e+01, -2.73250520e+01, -2.80052386e+01,
#        -3.39222236e+01, -3.39050718e+01, -3.74235465e+01, -3.66751551e+01,
#        -3.95084548e+01, -4.09851224e+01])

# %%
iend = 20
plt.scatter(np.log10((Pk_sum10["power"].real - Pk_sum10.attrs["shotnoise"]))[:iend], np.log10((Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:iend])
plt.plot([1,4], [1,4])
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10

# %%
np.log10(Pk_gal10["k"][20])
# Out:
# 0.015175432330778428

# %%
p1 = Pk_gal10["power"].real - (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]) - Pk_gal10.attrs["shotnoise"]

# %%
#fig,ax = plt.subplots()
figsize = (2*10/3,2*3)
fig1 = plt.figure(figsize=figsize)
ax = fig1.add_axes((.15,.3,.8,.5))
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10["power"].real)[:len_k], label="TNG total", color=color_list1[0])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10["power"].real)[:len_k], label="TNG total", color=color_list1[1])
plt.plot(np.log10(ks[:len_k]), np.log10(coef * (Pk_gal10["power"].real-Pk_gal10.attrs["shotnoise"]))[:len_k], linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
plt.scatter(np.log10(ks[:len_k]), np.log10(coef * (Pk_sum10["power"].real- Pk_sum10.attrs["shotnoise"]))[:len_k], label="TNG clustering (group)", color=color_list1[1], s=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_gal10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[0], linewidth=1)
plt.plot(np.log10(ks[:len_k]), np.log10(coef * Pk_sum10.attrs["shotnoise"])[:len_k], linestyle="dashdot", label="TNG shot noise", color=color_list1[1], linewidth=1)

plt.plot(np.log10(ks[:len_k]), np.log10(coef* p1)[:len_k])

plt.plot(np.log10(ks[:len_k]), np.log10(coef *(Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"]))[:len_k], label="Subtract shotnoise", color = color_list2[0], linestyle="dotted")
#plt.plot(np.log10(ks), np.log10(normed_Pk_matter_nl), label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
plt.xlabel(r"$\mathrm{log_{10}} (k\ \mathrm{[h\ Mpc^{-1}}])$")
plt.ylabel(r"$ \mathrm{log_{10}}(k^3 P(k)/2\pi^2)$")
#plt.xlim(-1.5, 0.5)

label_list = ["Galaxy", "Group"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list1[i], linestyle="solid", label=label)
    solid_lines.append(solid_line)

first_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right")
ax.add_artist(first_legend)


color="grey"
total_ps_leg = Line2D([],[],color=color, linestyle="solid", label=r"$P_\mathrm{tot}$")
shotnoise_subtracted_ps_leg = Line2D([],[],color=color,linestyle=(0, (1, 2)), label=r"$P_{\mathrm{clus}} = P_{\rm tot} - P_{\rm shot}$", linewidth=4)
shot_ps_leg = Line2D([],[],color=color, label=r"$P_{\mathrm{shot}}$", linewidth=2, linestyle="dashdot")

leg_list = [total_ps_leg, shot_ps_leg, shotnoise_subtracted_ps_leg]
leg = ax.legend(handles=leg_list,bbox_to_anchor=(0,0.5), loc="lower left", frameon=False)
ax.add_artist(leg)
plt.xlim(-1.55,1.3)
plt.xticks(color="w")
frame2 = fig1.add_axes((.15,.1,.8,.2))

linewidth1=1
plt.plot([-1.5,np.log10(ks[-1])],[1,1],  color=color_list1[1], linestyle="dotted")

#plt.plot(np.log10(ks[:len_k]), (Pk_gal10["power"].real/Pk_gal10["power"].real)[:len_k])
iend = 15
plt.plot(np.log10(ks[:iend]), (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend], linestyle="dotted", color=color_list2[0])
#plt.plot(np.log10(ks), coef * Pk_gal10["power"]/(pkgal2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[0])
#plt.plot(np.log10(ks), coef * Pk_sum10["power"][:iend]/(pksum2_ratio*normed_Pk_matter_lin), label="TNG total", color=color_list1[1])
#plt.plot(np.log10(ks),coef * (Pk_gal10["power"]-Pk_gal10.attrs["shotnoise"])/(pkgal2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (gal)", color=color_list1[0])
#plt.plot(np.log10(ks), coef * (Pk_sum10["power"][:iend]-Pk_sum10.attrs["shotnoise"])/(pksum2_ratio*normed_Pk_matter_lin), linestyle="dotted", label="TNG clustering (group)", color=color_list1[1])
#plt.plot(np.log10(ks), normed_Pk_matter_nl/normed_Pk_matter_lin, label="nonlinear x 4", color = color_list2[1], linestyle="dotted")
label_list = [r"$P_{\rm tot}^{\rm gal} - P_{\rm shot}^{\rm group}$"]
solid_lines = []
for i, label in enumerate(label_list):
    solid_line = Line2D([],[],color=color_list2[i], linestyle="dotted", label=label)
    solid_lines.append(solid_line)

ax = plt.gca()
second_legend = ax.legend(handles=solid_lines, frameon=False, loc="lower right", bbox_to_anchor = (1,0))
ax.add_artist(second_legend)

plt.xlabel(r"$\mathrm{log_{10}(}k\ \mathrm{[h\ Mpc^{-1}])}$")
#plt.ylim(0.9,2.5)
plt.ylabel(r"$\rm \dfrac{gal - group}{group - group}$", fontsize=16)
#plt.savefig("figures/tng_vs_matter.pdf", format="pdf", bbox_inches="tight")
plt.xlim(-1.55,1.3)
plt.ylim(0.97, 1.005)
#plt.ylim(0.999, 1.005)
#plt.savefig("../figures/one_halo_term.pdf", format="pdf", bbox_inches="tight")
# Out:
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log10
#
# /cosma/local/Python/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in log10
#   from ipykernel import kernelapp as app
# (0.97, 1.005)

# %%
 (Pk_gal10["power"].real - Pk_sum10.attrs["shotnoise"])[:iend]/(Pk_sum10["power"].real-Pk_sum10.attrs["shotnoise"])[:iend]
# Out:
# array([1.00010851, 1.0005087 , 1.00042262, 0.99999659, 0.998768  ,
#        0.99980858, 1.00012486, 0.99745657, 0.99321784, 0.99471489,
#        0.9932313 , 0.98827612, 0.98697037, 0.97915314, 0.96907627])

# %%
np.log10(ks[:iend])
# Out:
# array([-1.36238137, -1.06033514, -0.85899556, -0.72547219, -0.62661139,
#        -0.54272912, -0.473019  , -0.41424163, -0.36117288, -0.31354678,
#        -0.27102314, -0.23226579, -0.19665425, -0.16393475, -0.13327703])

# %%
(1.00010851-1)*100
# Out:
# 0.01085100000000061
