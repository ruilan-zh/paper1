# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

import sys
    
    
sys.path.insert(0, '/cosma/home/dp004/dc-zhan5')
import MyHaloPS as ps
import importlib
importlib.reload(ps)
import pickle

# %%
import seaborn as sns
palette_tab10 = sns.color_palette("colorblind", 10)

# %%
odir = "../ps_data"
with open(f"{odir}/snap40/mvir/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10 = pickle.load(f)
    Pk_gal10 = pickle.load(f)
print("shotnoise", Pk_gal10.attrs["shotnoise"])
# Out:
# shotnoise 130.38519438706473

# %%
with open(f"{odir}/snap40/mvir/SubhaloFlag=1/ps-intensity-gal_logM10.pickle", "rb") as f:
    Pk_mean_gal10_flag1 = pickle.load(f)
    Pk_gal10_flag1 = pickle.load(f)
print("shotnoise", Pk_gal10_flag1.attrs["shotnoise"])
# Out:
# shotnoise 134.64551712053185

# %%
ps.compare_ps_plot([Pk_gal10, Pk_gal10_flag1], labels=["All", "SubhaloFlag=1"], residuals_only=True, ratio_ylabel_list=["All", "SubhaloFlag=1"], bbox_to_anchor_grey=(0.6,0.7), bbox_to_anchor_color=(0.3,1), color_list=palette_tab10[3:4] + ["DodgerBlue"], shotnoise_subtracted_ps=False)
#plt.savefig("../figures/SubhaloFlag_ps.pdf", format="pdf", bbox_inches="tight")
#plt.ylim(0.5,1.1)
# Out:
# shotnoise:  130.38519438706473
# shotnoise:  134.64551712053185

# %%
ps.residual_plot([Pk_gal10, Pk_gal10_flag1], labels=["All", "SubhaloFlag=1"], ratio_ylabel_list=["Galaxies","Central"], bbox_to_anchor_color=(0.3,1), color_list=palette_tab10[3:4] + ["DodgerBlue"])
#plt.savefig("figures/cent_vs_gal.pdf", format="pdf", bbox_inches="tight")
#plt.ylim(0.5,1.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7076fc68c00c> in <module>()
# ----> 1 ps.residual_plot([Pk_gal10, Pk_gal10_flag1], labels=["All", "SubhaloFlag=1"], ratio_ylabel_list=["Galaxies","Central"], bbox_to_anchor_color=(0.3,1), color_list=palette_tab10[3:4] + ["DodgerBlue"])
#       2 #plt.savefig("figures/cent_vs_gal.pdf", format="pdf", bbox_inches="tight")
#       3 #plt.ylim(0.5,1.1)
#
# TypeError: residual_plot() missing 1 required positional argument: 'mean_of_seeds_lists'
